# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from HelperMethods import *

# %%
this = %pwd

# %%
PATH = (f'{this}/').replace('NoteBook/','')+'Data/'

# %%
column_names = ["sex", "length", "diameter", "height", "whole weight", 
                "shucked weight", "viscera weight", "shell weight", "rings"]
df = pd.read_csv(PATH + "abalone.data", names=column_names)

# %%
df.shape
# Out:
# (4177, 9)

# %%
df.head(50)
# Out:
#    sex  length  diameter  height  whole weight  shucked weight  \
# 0    M   0.455     0.365   0.095        0.5140          0.2245
# 1    M   0.350     0.265   0.090        0.2255          0.0995
# 2    F   0.530     0.420   0.135        0.6770          0.2565
# 3    M   0.440     0.365   0.125        0.5160          0.2155
# 4    I   0.330     0.255   0.080        0.2050          0.0895
# 5    I   0.425     0.300   0.095        0.3515          0.1410
# 6    F   0.530     0.415   0.150        0.7775          0.2370
# 7    F   0.545     0.425   0.125        0.7680          0.2940
# 8    M   0.475     0.370   0.125        0.5095          0.2165
# 9    F   0.550     0.440   0.150        0.8945          0.3145
# 10   F   0.525     0.380   0.140        0.6065          0.1940
# 11   M   0.430     0.350   0.110        0.4060          0.1675
# 12   M   0.490     0.380   0.135        0.5415          0.2175
# 13   F   0.535     0.405   0.145        0.6845          0.2725
# 14   F   0.470     0.355   0.100        0.4755          0.1675
# 15   M   0.500     0.400   0.130        0.6645          0.2580
# 16   I   0.355     0.280   0.085        0.2905          0.0950
# 17   F   0.440     0.340   0.100        0.4510          0.1880
# 18   M   0.365     0.295   0.080        0.2555          0.0970
# 19   M   0.450     0.320   0.100        0.3810          0.1705
# 20   M   0.355     0.280   0.095        0.2455          0.0955
# 21   I   0.380     0.275   0.100        0.2255          0.0800
# 22   F   0.565     0.440   0.155        0.9395          0.4275
# 23   F   0.550     0.415   0.135        0.7635          0.3180
# 24   F   0.615     0.480   0.165        1.1615          0.5130
# 25   F   0.560     0.440   0.140        0.9285          0.3825
# 26   F   0.580     0.450   0.185        0.9955          0.3945
# 27   M   0.590     0.445   0.140        0.9310          0.3560
# 28   M   0.605     0.475   0.180        0.9365          0.3940
# 29   M   0.575     0.425   0.140        0.8635          0.3930
# 30   M   0.580     0.470   0.165        0.9975          0.3935
# 31   F   0.680     0.560   0.165        1.6390          0.6055
# 32   M   0.665     0.525   0.165        1.3380          0.5515
# 33   F   0.680     0.550   0.175        1.7980          0.8150
# 34   F   0.705     0.550   0.200        1.7095          0.6330
# 35   M   0.465     0.355   0.105        0.4795          0.2270
# 36   F   0.540     0.475   0.155        1.2170          0.5305
# 37   F   0.450     0.355   0.105        0.5225          0.2370
# 38   F   0.575     0.445   0.135        0.8830          0.3810
# 39   M   0.355     0.290   0.090        0.3275          0.1340
# 40   F   0.450     0.335   0.105        0.4250          0.1865
# 41   F   0.550     0.425   0.135        0.8515          0.3620
# 42   I   0.240     0.175   0.045        0.0700          0.0315
# 43   I   0.205     0.150   0.055        0.0420          0.0255
# 44   I   0.210     0.150   0.050        0.0420          0.0175
# 45   I   0.390     0.295   0.095        0.2030          0.0875
# 46   M   0.470     0.370   0.120        0.5795          0.2930
# 47   F   0.460     0.375   0.120        0.4605          0.1775
# 48   I   0.325     0.245   0.070        0.1610          0.0755
# 49   F   0.525     0.425   0.160        0.8355          0.3545
#
#     viscera weight  shell weight  rings
# 0           0.1010         0.150     15
# 1           0.0485         0.070      7
# 2           0.1415         0.210      9
# 3           0.1140         0.155     10
# 4           0.0395         0.055      7
# 5           0.0775         0.120      8
# 6           0.1415         0.330     20
# 7           0.1495         0.260     16
# 8           0.1125         0.165      9
# 9           0.1510         0.320     19
# 10          0.1475         0.210     14
# 11          0.0810         0.135     10
# 12          0.0950         0.190     11
# 13          0.1710         0.205     10
# 14          0.0805         0.185     10
# 15          0.1330         0.240     12
# 16          0.0395         0.115      7
# 17          0.0870         0.130     10
# 18          0.0430         0.100      7
# 19          0.0750         0.115      9
# 20          0.0620         0.075     11
# 21          0.0490         0.085     10
# 22          0.2140         0.270     12
# 23          0.2100         0.200      9
# 24          0.3010         0.305     10
# 25          0.1880         0.300     11
# 26          0.2720         0.285     11
# 27          0.2340         0.280     12
# 28          0.2190         0.295     15
# 29          0.2270         0.200     11
# 30          0.2420         0.330     10
# 31          0.2805         0.460     15
# 32          0.3575         0.350     18
# 33          0.3925         0.455     19
# 34          0.4115         0.490     13
# 35          0.1240         0.125      8
# 36          0.3075         0.340     16
# 37          0.1165         0.145      8
# 38          0.2035         0.260     11
# 39          0.0860         0.090      9
# 40          0.0910         0.115      9
# 41          0.1960         0.270     14
# 42          0.0235         0.020      5
# 43          0.0150         0.012      5
# 44          0.0125         0.015      4
# 45          0.0450         0.075      7
# 46          0.2270         0.140      9
# 47          0.1100         0.150      7
# 48          0.0255         0.045      6
# 49          0.2135         0.245      9

# %%
X = df.drop('rings', axis='columns')
y = df['rings']

# %%
d = {'M': 1, 'F': 2, 'I': 3}
X['sex'].replace(d,inplace = True)

X.head(10)
# Out:
#    sex  length  diameter  height  whole weight  shucked weight  \
# 0    1   0.455     0.365   0.095        0.5140          0.2245
# 1    1   0.350     0.265   0.090        0.2255          0.0995
# 2    2   0.530     0.420   0.135        0.6770          0.2565
# 3    1   0.440     0.365   0.125        0.5160          0.2155
# 4    3   0.330     0.255   0.080        0.2050          0.0895
# 5    3   0.425     0.300   0.095        0.3515          0.1410
# 6    2   0.530     0.415   0.150        0.7775          0.2370
# 7    2   0.545     0.425   0.125        0.7680          0.2940
# 8    1   0.475     0.370   0.125        0.5095          0.2165
# 9    2   0.550     0.440   0.150        0.8945          0.3145
#
#    viscera weight  shell weight
# 0          0.1010         0.150
# 1          0.0485         0.070
# 2          0.1415         0.210
# 3          0.1140         0.155
# 4          0.0395         0.055
# 5          0.0775         0.120
# 6          0.1415         0.330
# 7          0.1495         0.260
# 8          0.1125         0.165
# 9          0.1510         0.320

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42)
print(X_test.values[:, 0])
# Out:
# [1. 1. 2. ... 1. 1. 2.]

# %%
def value_count(x, threshold):
    result = {}
    result[0] = 0
    result[1] = 0
    for value in x:
        if value <= threshold:
            result[0] += 1
        else:
            result[1]+=1
    return result

def target_value_count(y):
    result = {}
    for value in y:
        if value not in result:
            result[value] = 1
        else:
            result[value]+=1
    return result
    
    
def entropy(y, val_type, threshold = None):
    if val_type == "target":
        result = target_value_count(y)
        entropy = 0
        for value in result.values():
            p = value/len(y)
            entropy -= p*log2(p)
        return entropy
    else:
        result= value_count(y, threshold)
        entropy = 0
        for idx in range(2):
            p = result[idx]/len(y)
            entropy -= p*log2(p)
        return entropy

# %%
ja = X_train.index
print(ja.values)
# Out:
# [3823 3956 3623 ... 3092 3772  860]

# %% [markdown]
# # text

# %%
def information_gain(attribute, target, method):
    target_entropy = entropy(target, "target")
    #print(target_entropy)
    info_gains = []
    for attr in attribute:
        threshold = np.mean(attribute[attr])
        le_idx = np.where(attribute[attr] <= threshold)
        g_idx = np.where(attribute[attr] > threshold)
        y_le = target.values[le_idx]
        y_g = target.values[g_idx]
        # count hvor mange av hver ring som er i <= og >
        # ta count/len * log2 len/count
        le_entropy = entropy(y_le, "target")
        g_entropy = entropy(y_g, "target")
        
        
        attr_entropy = (len(y_le)/len(attribute[attr]))*le_entropy + (len(y_g)/len(attribute[attr]))*g_entropy
        information_gain = target_entropy - attr_entropy
        info_gains.append(information_gain)
    return np.argmax(info_gains)

# %%
def make_tree(X, y, n, impurity_measure):
    if len(X) == 0:
        return
    else:
        x_copy = X.copy()
        y_copy = y.copy()
        
        top_ig = information_gain(x_copy, y_copy, "entropy")
        threshold = np.mean(x_copy[x_copy.columns[top_ig]])
        le_idx = np.where(x_copy[x_copy.columns[top_ig]] <= threshold)
        g_idx = np.where(x_copy[x_copy.columns[top_ig]] > threshold)
    
        n.category = top_ig
        n.data = threshold
    
        left_child = mnode()
        right_child = mnode()
        left_child.parent = n
        right_child.parent = n
        
        left_child.data = le_idx
        right_child.data = g_idx
        
        #node.children[0] = left_child
        #node.children[1] = right_child
        
        n.add_child(1, le_idx, left_child)
        n.add_child(2, g_idx, right_child)
        for child in n.children:
            X_copy = pd.DataFrame(x_copy.values[child.data])
            Y_copy = pd.Series(y_copy.values[child.data])
            
            if(len(X_copy) == 1):
                child.isLeaf = True
                child.data = Y_copy[X_copy.index]
            elif len(np.unique(Y_copy.values)) == 1:
                child.isLeaf = True
                child.data = Y_copy.sample(n = 1)
            elif len(target_value_count(X_copy)) == 1:
                child.isleaf = True
                child.data = Y_copy.value_counts().argmax()
            else:
                learn(X_copy, Y_copy, child, "entropy")

# %%
class mnode(object):
    
    def __init__(self):
        self.data = None
        self.parent = None
        self.children = []
        self.category = None
        self.isLeaf = False
        self.category = None
    
    def add_child(self, name, threshold, child):
        child.data = threshold
        self.children.append(child)

# %%
n = mnode()
learn(X_train, y_train, n, "entropy")
print(n.data)
# Out:
# 0.24035089399744528

# %%
def printer(n):
    print(n.data)
    for child in n.children:
        if child.children != None:
            print(child.data)
            print(child.category)
            printer(child)

# %%
printer(n)
# Out:
# 0.24035089399744528
# 0.13220343137254903
# 7
# 0.13220343137254903
# 0.2765394242803504
# 2
# 0.2765394242803504
# 0.22159663865546197
# 2
# 0.22159663865546197
# 0.024089403973509907
# 7
# 0.024089403973509907
# 0.018020833333333323
# 5
# 0.018020833333333323
# 0.008675675675675681
# 7
# 0.008675675675675681
# 0.007176470588235295
# 5
# 0.007176470588235295
# 0.10222222222222223
# 2
# 0.10222222222222223
# 0.11833333333333335
# 1
# 0.11833333333333335
# 0    1
# dtype: int64
# None
# 0    1
# dtype: int64
# 0.14
# 1
# 0.14
# 0    3
# dtype: int64
# None
# 0    3
# dtype: int64
# 0    2
# dtype: int64
# None
# 0    2
# dtype: int64
# 0.005916666666666666
# 5
# 0.005916666666666666
# 0    4
# dtype: int64
# None
# 0    4
# dtype: int64
# 2.3333333333333335
# 0
# 2.3333333333333335
# 0    3
# dtype: int64
# None
# 0    3
# dtype: int64
# 0.11499999999999999
# 2
# 0.11499999999999999
# 0    4
# dtype: int64
# None
# 0    4
# dtype: int64
# 0    3
# dtype: int64
# None
# 0    3
# dtype: int64
# 0.0065625
# 7
# 0.0065625
# 2    4
# dtype: int64
# None
# 2    4
# dtype: int64
# 0.12375
# 2
# 0.12375
# 0    5
# dtype: int64
# None
# 0    5
# dtype: int64
# 0.045000000000000005
# 3
# 0.045000000000000005
# 0    4
# dtype: int64
# None
# 0    4
# dtype: int64
# 0    6
# dtype: int64
# None
# 0    6
# dtype: int64
# 0.011400000000000004
# 7
# 0.011400000000000004
# 0.045769230769230757
# 3
# 0.045769230769230757
# 0.012277777777777776
# 5
# 0.012277777777777776
# 0.134
# 2
# 0.134
# 0    4
# dtype: int64
# None
# 0    4
# dtype: int64
# 0.19000000000000003
# 1
# 0.19000000000000003
# 0.042499999999999996
# 3
# 0.042499999999999996
# 0    5
# dtype: int64
# None
# 0    5
# dtype: int64
# 0    4
# dtype: int64
# None
# 0    4
# dtype: int64
# 0    5
# dtype: int64
# None
# 0    5
# dtype: int64
# 0.19374999999999998
# 1
# 0.19374999999999998
# 1    3
# dtype: int64
# None
# 1    3
# dtype: int64
# 0.2025
# 1
# 0.2025
# 0    3
# dtype: int64
# None
# 0    3
# dtype: int64
# 0    4
# dtype: int64
# None
# 0    4
# dtype: int64
# 1.5
# 0
# 1.5
# 0.051666666666666666
# 3
# 0.051666666666666666
# 1    3
# dtype: int64
# None
# 1    3
# dtype: int64
# 0    5
# dtype: int64
# None
# 0    5
# dtype: int64
# 0    5
# dtype: int64
# None
# 0    5
# dtype: int64
# 2.142857142857143
# 0
# 2.142857142857143
# 0.042
# 4
# 0.042
# 0    4
# dtype: int64
# None
# 0    4
# dtype: int64
# 1    7
# dtype: int64
# None
# 1    7
# dtype: int64
# 0.19
# 1
# 0.19
# 0.16999999999999998
# 1
# 0.16999999999999998
# 0    3
# dtype: int64
# None
# 0    3
# dtype: int64
# 0    5
# dtype: int64
# None
# 0    5
# dtype: int64
# 0.21
# 1
# 0.21
# 0    6
# dtype: int64
# None
# 0    6
# dtype: int64
# 0    3
# dtype: int64
# None
# 0    3
# dtype: int64
# 0.013885714285714291
# 6
# 0.013885714285714291
# 0.010382352941176473
# 6
# 0.010382352941176473
# 0    4
# dtype: int64
# None
# 0    4
# dtype: int64
# 0.017227272727272726
# 7
# 0.017227272727272726
# 0.022750000000000003
# 5
# 0.022750000000000003
# 0.21333333333333335
# 1
# 0.21333333333333335
# 0.2075
# 1
# 0.2075
# 0    4
# dtype: int64
# None
# 0    4
# dtype: int64
# 0    5
# dtype: int64
# None
# 0    5
# dtype: int64
# 0    4
# dtype: int64
# None
# 0    4
# dtype: int64
# 0.2233333333333333
# 1
# 0.2233333333333333
# 0    3
# dtype: int64
# None
# 0    3
# dtype: int64
# 0.23249999999999998
# 1
# 0.23249999999999998
# 0    4
# dtype: int64
# None
# 0    4
# dtype: int64
# 0    3
# dtype: int64
# None
# 0    3
# dtype: int64
# 0.238
# 1
# 0.238
# 0    5
# dtype: int64
# None
# 0    5
# dtype: int64
# 1    4
# dtype: int64
# None
# 1    4
# dtype: int64
# 0.07005555555555557
# 4
# 0.07005555555555557
# 0.06294444444444444
# 4
# 0.06294444444444444
# 0.227
# 1
# 0.227
# 0.1625
# 2
# 0.1625
# 0    5
# dtype: int64
# None
# 0    5
# dtype: int64
# 0    6
# dtype: int64
# None
# 0    6
# dtype: int64
# 0    6
# dtype: int64
# None
# 0    6
# dtype: int64
# 1    5
# dtype: int64
# None
# 1    5
# dtype: int64
# 0.185
# 2
# 0.185
# 0.24928571428571425
# 1
# 0.24928571428571425
# 0    5
# dtype: int64
# None
# 0    5
# dtype: int64
# 0.183
# 2
# 0.183
# 0    4
# dtype: int64
# None
# 0    4
# dtype: int64
# 0.021833333333333333
# 7
# 0.021833333333333333
# 0    4
# dtype: int64
# None
# 0    4
# dtype: int64
# 0    5
# dtype: int64
# None
# 0    5
# dtype: int64
# 0    4
# dtype: int64
# None
# 0    4
# dtype: int64
# 0.025088607594936713
# 6
# 0.025088607594936713
# 0.030864583333333338
# 7
# 0.030864583333333338
# 0.06633333333333334
# 3
# 0.06633333333333334
# 0.038058823529411756
# 5
# 0.038058823529411756
# 0.033749999999999995
# 5
# 0.033749999999999995
# 0.05625
# 3
# 0.05625
# 0    6
# dtype: int64
# None
# 0    6
# dtype: int64
# 2.0
# 0
# 2.0
# 0    8
# dtype: int64
# None
# 0    8
# dtype: int64
# 0    5
# dtype: int64
# None
# 0    5
# dtype: int64
# 0.2708333333333333
# 1
# 0.2708333333333333
# 0.26
# 1
# 0.26
# 0    6
# dtype: int64
# None
# 0    6
# dtype: int64
# 1    7
# dtype: int64
# None
# 1    7
# dtype: int64
# 0.2816666666666667
# 1
# 0.2816666666666667
# 0.2775
# 1
# 0.2775
# 0    4
# dtype: int64
# None
# 0    4
# dtype: int64
# 0    7
# dtype: int64
# None
# 0    7
# dtype: int64
# 0    6
# dtype: int64
# None
# 0    6
# dtype: int64
# 0.09892857142857141
# 4
# 0.09892857142857141
# 2    5
# dtype: int64
# None
# 2    5
# dtype: int64
# 0.2783333333333334
# 1
# 0.2783333333333334
# 0.2725
# 1
# 0.2725
# 0    5
# dtype: int64
# None
# 0    5
# dtype: int64
# 0    7
# dtype: int64
# None
# 0    7
# dtype: int64
# 0    6
# dtype: int64
# None
# 0    6
# dtype: int64
# 2.3076923076923075
# 0
# 2.3076923076923075
# 0.27199999999999996
# 1
# 0.27199999999999996
# 1    6
# dtype: int64
# None
# 1    6
# dtype: int64
# 1    5
# dtype: int64
# None
# 1    5
# dtype: int64
# 0.265
# 1
# 0.265
# 0.19625
# 2
# 0.19625
# 0    6
# dtype: int64
# None
# 0    6
# dtype: int64
# 0.2025
# 2
# 0.2025
# 0    6
# dtype: int64
# None
# 0    6
# dtype: int64
# 0    4
# dtype: int64
# None
# 0    4
# dtype: int64
# 1    6
# dtype: int64
# None
# 1    6
# dtype: int64
# 0.06833333333333334
# 3
# 0.06833333333333334
# 0.035375000000000004
# 7
# 0.035375000000000004
# 3    5
# dtype: int64
# None
# 3    5
# dtype: int64
# 0.2783333333333333
# 1
# 0.2783333333333333
# 0    4
# dtype: int64
# None
# 0    4
# dtype: int64
# 0.3025
# 1
# 0.3025
# 0    4
# dtype: int64
# None
# 0    4
# dtype: int64
# 0    5
# dtype: int64
# None
# 0    5
# dtype: int64
# 0.10530000000000002
# 4
# 0.10530000000000002
# 0.28200000000000003
# 1
# 0.28200000000000003
# 0.035666666666666666
# 5
# 0.035666666666666666
# 1    5
# dtype: int64
# None
# 1    5
# dtype: int64
# 0    8
# dtype: int64
# None
# 0    8
# dtype: int64
# 1    8
# dtype: int64
# None
# 1    8
# dtype: int64
# 0.0205
# 6
# 0.0205
# 2.0
# 0
# 2.0
# 0    7
# dtype: int64
# None
# 0    7
# dtype: int64
# 0    6
# dtype: int64
# None
# 0    6
# dtype: int64
# 2    5
# dtype: int64
# None
# 2    5
# dtype: int64
# 0.20741935483870969
# 2
# 0.20741935483870969
# 0.034
# 6
# 0.034
# 0.079375
# 3
# 0.079375
# 0.07125000000000001
# 3
# 0.07125000000000001
# 1    6
# dtype: int64
# None
# 1    6
# dtype: int64
# 1    4
# dtype: int64
# None
# 1    4
# dtype: int64
# 0.20124999999999998
# 2
# 0.20124999999999998
# 1    6
# dtype: int64
# None
# 1    6
# dtype: int64
# 1    5
# dtype: int64
# None
# 1    5
# dtype: int64
# 0.2733333333333334
# 1
# 0.2733333333333334
# 0    5
# dtype: int64
# None
# 0    5
# dtype: int64
# 0.2775
# 1
# 0.2775
# 0    5
# dtype: int64
# None
# 0    5
# dtype: int64
# 0    9
# dtype: int64
# None
# 0    9
# dtype: int64
# 0.07425000000000001
# 3
# 0.07425000000000001
# 0.21555555555555556
# 2
# 0.21555555555555556
# 0.0625
# 3
# 0.0625
# 1    5
# dtype: int64
# None
# 1    5
# dtype: int64
# 0.2825
# 1
# 0.2825
# 0    6
# dtype: int64
# None
# 0    6
# dtype: int64
# 0    5
# dtype: int64
# None
# 0    5
# dtype: int64
# 0.29799999999999993
# 1
# 0.29799999999999993
# 2    6
# dtype: int64
# None
# 2    6
# dtype: int64
# 0    5
# dtype: int64
# None
# 0    5
# dtype: int64
# 2.5454545454545454
# 0
# 2.5454545454545454
# 1    6
# dtype: int64
# None
# 1    6
# dtype: int64
# 0.291875
# 1
# 0.291875
# 0.049249999999999995
# 5
# 0.049249999999999995
# 0.2775
# 1
# 0.2775
# 0    7
# dtype: int64
# None
# 0    7
# dtype: int64
# 0    4
# dtype: int64
# None
# 0    4
# dtype: int64
# 0    6
# dtype: int64
# None
# 0    6
# dtype: int64
# 0.17587499999999998
# 4
# 0.17587499999999998
# 0.05733333333333334
# 5
# 0.05733333333333334
# 1    7
# dtype: int64
# None
# 1    7
# dtype: int64
# 0    5
# dtype: int64
# None
# 0    5
# dtype: int64
# 0    6
# dtype: int64
# None
# 0    6
# dtype: int64
# 2.4902912621359223
# 0
# 2.4902912621359223
# 0.2535344827586208
# 2
# 0.2535344827586208
# 0.06265909090909091
# 5
# 0.06265909090909091
# 0.05223076923076924
# 5
# 0.05223076923076924
# 0.03208333333333333
# 6
# 0.03208333333333333
# 1.3333333333333333
# 0
# 1.3333333333333333
# 0.2925
# 1
# 0.2925
# 0    7
# dtype: int64
# None
# 0    7
# dtype: int64
# 0    8
# dtype: int64
# None
# 0    8
# dtype: int64
# 0    5
# dtype: int64
# None
# 0    5
# dtype: int64
# 0    9
# dtype: int64
# None
# 0    9
# dtype: int64
# 0.31428571428571433
# 1
# 0.31428571428571433
# 0.3033333333333333
# 1
# 0.3033333333333333
# 0    10
# dtype: int64
# None
# 0    10
# dtype: int64
# 1    7
# dtype: int64
# None
# 1    7
# dtype: int64
# 0.3225
# 1
# 0.3225
# 0    11
# dtype: int64
# None
# 0    11
# dtype: int64
# 0.3275
# 1
# 0.3275
# 0    4
# dtype: int64
# None
# 0    4
# dtype: int64
# 0    10
# dtype: int64
# None
# 0    10
# dtype: int64
# 0.24000000000000002
# 2
# 0.24000000000000002
# 0.04078571428571428
# 6
# 0.04078571428571428
# 1.2
# 0
# 1.2
# 0.32
# 1
# 0.32
# 0    6
# dtype: int64
# None
# 0    6
# dtype: int64
# 0.33
# 1
# 0.33
# 0    7
# dtype: int64
# None
# 0    7
# dtype: int64
# 0    6
# dtype: int64
# None
# 0    6
# dtype: int64
# 0    7
# dtype: int64
# None
# 0    7
# dtype: int64
# 0    7
# dtype: int64
# None
# 0    7
# dtype: int64
# 1.5
# 0
# 1.5
# 0    10
# dtype: int64
# None
# 0    10
# dtype: int64
# 0    6
# dtype: int64
# None
# 0    6
# dtype: int64
# 0.35263888888888895
# 1
# 0.35263888888888895
# 0.08088636363636365
# 5
# 0.08088636363636365
# 0.18666666666666665
# 4
# 0.18666666666666665
# 1.1428571428571428
# 0
# 1.1428571428571428
# 0.34416666666666673
# 1
# 0.34416666666666673
# 0.3375
# 1
# 0.3375
# 0    8
# dtype: int64
# None
# 0    8
# dtype: int64
# 0    10
# dtype: int64
# None
# 0    10
# dtype: int64
# 0.3475
# 1
# 0.3475
# 0    10
# dtype: int64
# None
# 0    10
# dtype: int64
# 0.26
# 2
# 0.26
# 0    10
# dtype: int64
# None
# 0    10
# dtype: int64
# 0    12
# dtype: int64
# None
# 0    12
# dtype: int64
# 0    7
# dtype: int64
# None
# 0    7
# dtype: int64
# 0.197375
# 4
# 0.197375
# 0.343
# 1
# 0.343
# 0    7
# dtype: int64
# None
# 0    7
# dtype: int64
# 0    9
# dtype: int64
# None
# 0    9
# dtype: int64
# 0.09166666666666667
# 3
# 0.09166666666666667
# 0    10
# dtype: int64
# None
# 0    10
# dtype: int64
# 0    9
# dtype: int64
# None
# 0    9
# dtype: int64
# 0.3457142857142857
# 1
# 0.3457142857142857
# 0.25666666666666665
# 2
# 0.25666666666666665
# 1    9
# dtype: int64
# None
# 1    9
# dtype: int64
# 0    6
# dtype: int64
# None
# 0    6
# dtype: int64
# 0.2675
# 2
# 0.2675
# 0.09666666666666668
# 3
# 0.09666666666666668
# 0.226
# 4
# 0.226
# 0    7
# dtype: int64
# None
# 0    7
# dtype: int64
# 0    6
# dtype: int64
# None
# 0    6
# dtype: int64
# 0    7
# dtype: int64
# None
# 0    7
# dtype: int64
# 0    8
# dtype: int64
# None
# 0    8
# dtype: int64
# 1.3571428571428572
# 0
# 1.3571428571428572
# 0.2242222222222222
# 4
# 0.2242222222222222
# 0.07785714285714286
# 5
# 0.07785714285714286
# 1    8
# dtype: int64
# None
# 1    8
# dtype: int64
# 1    6
# dtype: int64
# None
# 1    6
# dtype: int64
# 0    8
# dtype: int64
# None
# 0    8
# dtype: int64
# 0.364
# 1
# 0.364
# 0.26666666666666666
# 2
# 0.26666666666666666
# 0.2115
# 4
# 0.2115
# 0    8
# dtype: int64
# None
# 0    8
# dtype: int64
# 0    10
# dtype: int64
# None
# 0    10
# dtype: int64
# 0    5
# dtype: int64
# None
# 0    5
# dtype: int64
# 1    8
# dtype: int64
# None
# 1    8
# dtype: int64
# 0.05739864864864862
# 7
# 0.05739864864864862
# 0.16205128205128203
# 4
# 0.16205128205128203
# 0.031925
# 6
# 0.031925
# 0.05744
# 5
# 0.05744
# 0.13084615384615386
# 4
# 0.13084615384615386
# 0.04721428571428571
# 5
# 0.04721428571428571
# 0.3033333333333333
# 1
# 0.3033333333333333
# 0.2975
# 1
# 0.2975
# 0    7
# dtype: int64
# None
# 0    7
# dtype: int64
# 0    8
# dtype: int64
# None
# 0    8
# dtype: int64
# 0    5
# dtype: int64
# None
# 0    5
# dtype: int64
# 1    6
# dtype: int64
# None
# 1    6
# dtype: int64
# 0.07416666666666667
# 3
# 0.07416666666666667
# 0    8
# dtype: int64
# None
# 0    8
# dtype: int64
# 0.30833333333333335
# 1
# 0.30833333333333335
# 0    4
# dtype: int64
# None
# 0    4
# dtype: int64
# 0.3125
# 1
# 0.3125
# 0    7
# dtype: int64
# None
# 0    7
# dtype: int64
# 0    5
# dtype: int64
# None
# 0    5
# dtype: int64
# 0.027749999999999997
# 6
# 0.027749999999999997
# 0.04157142857142856
# 7
# 0.04157142857142856
# 0.23625
# 2
# 0.23625
# 0.3175
# 1
# 0.3175
# 0    6
# dtype: int64
# None
# 0    6
# dtype: int64
# 0    7
# dtype: int64
# None
# 0    7
# dtype: int64
# 0    6
# dtype: int64
# None
# 0    6
# dtype: int64
# 0.3216666666666667
# 1
# 0.3216666666666667
# 0    5
# dtype: int64
# None
# 0    5
# dtype: int64
# 0    6
# dtype: int64
# None
# 0    6
# dtype: int64
# 1    6
# dtype: int64
# None
# 1    6
# dtype: int64
# 0.061099999999999995
# 5
# 0.061099999999999995
# 0.05506249999999999
# 5
# 0.05506249999999999
# 0.305
# 1
# 0.305
# 0    9
# dtype: int64
# None
# 0    9
# dtype: int64
# 0    7
# dtype: int64
# None
# 0    7
# dtype: int64
# 0.14533333333333331
# 4
# 0.14533333333333331
# 0.32
# 1
# 0.32
# 0    6
# dtype: int64
# None
# 0    6
# dtype: int64
# 0.2475
# 2
# 0.2475
# 0    6
# dtype: int64
# None
# 0    6
# dtype: int64
# 0    5
# dtype: int64
# None
# 0    5
# dtype: int64
# 0.07333333333333335
# 3
# 0.07333333333333335
# 0    7
# dtype: int64
# None
# 0    7
# dtype: int64
# 0    5
# dtype: int64
# None
# 0    5
# dtype: int64
# 0.15292857142857144
# 4
# 0.15292857142857144
# 0.3075
# 1
# 0.3075
# 0.2975
# 1
# 0.2975
# 0    9
# dtype: int64
# None
# 0    9
# dtype: int64
# 0    6
# dtype: int64
# None
# 0    6
# dtype: int64
# 1    6
# dtype: int64
# None
# 1    6
# dtype: int64
# 0.32499999999999996
# 1
# 0.32499999999999996
# 0.3125
# 1
# 0.3125
# 0    7
# dtype: int64
# None
# 0    7
# dtype: int64
# 0    13
# dtype: int64
# None
# 0    13
# dtype: int64
# 0    6
# dtype: int64
# None
# 0    6
# dtype: int64
# 0.08131578947368422
# 3
# 0.08131578947368422
# 0.04195
# 6
# 0.04195
# 0.07549999999999998
# 3
# 0.07549999999999998
# 0.074375
# 3
# 0.074375
# 0    7
# dtype: int64
# None
# 0    7
# dtype: int64
# 0.17614285714285713
# 4
# 0.17614285714285713
# 0.3333333333333333
# 1
# 0.3333333333333333
# 0.325
# 1
# 0.325
# 0    7
# dtype: int64
# None
# 0    7
# dtype: int64
# 0    6
# dtype: int64
# None
# 0    6
# dtype: int64
# 0    6
# dtype: int64
# None
# 0    6
# dtype: int64
# 0.18175
# 4
# 0.18175
# 0.2525
# 2
# 0.2525
# 0    7
# dtype: int64
# None
# 0    7
# dtype: int64
# 0    6
# dtype: int64
# None
# 0    6
# dtype: int64
# 0    7
# dtype: int64
# None
# 0    7
# dtype: int64
# 0    7
# dtype: int64
# None
# 0    7
# dtype: int64
# 0.33
# 1
# 0.33
# 0.315
# 1
# 0.315
# 1    5
# dtype: int64
# None
# 1    5
# dtype: int64
# 0.245
# 2
# 0.245
# 0    6
# dtype: int64
# None
# 0    6
# dtype: int64
# 0    5
# dtype: int64
# None
# 0    5
# dtype: int64
# 0.25166666666666665
# 2
# 0.25166666666666665
# 0.33999999999999997
# 1
# 0.33999999999999997
# 0.0775
# 3
# 0.0775
# 0    7
# dtype: int64
# None
# 0    7
# dtype: int64
# 0    6
# dtype: int64
# None
# 0    6
# dtype: int64
# 1    7
# dtype: int64
# None
# 1    7
# dtype: int64
# 0.2625
# 2
# 0.2625
# 0    6
# dtype: int64
# None
# 0    6
# dtype: int64
# 0    5
# dtype: int64
# None
# 0    5
# dtype: int64
# 0.08574999999999998
# 5
# 0.08574999999999998
# 0.3375
# 1
# 0.3375
# 0.246
# 2
# 0.246
# 0.3225
# 1
# 0.3225
# 0    7
# dtype: int64
# None
# 0    7
# dtype: int64
# 0    6
# dtype: int64
# None
# 0    6
# dtype: int64
# 0.33
# 1
# 0.33
# 0    8
# dtype: int64
# None
# 0    8
# dtype: int64
# 0.2525
# 2
# 0.2525
# 0    8
# dtype: int64
# None
# 0    8
# dtype: int64
# 0    9
# dtype: int64
# None
# 0    9
# dtype: int64
# 0.07780000000000001
# 5
# 0.07780000000000001
# 3    6
# dtype: int64
# None
# 3    6
# dtype: int64
# 0    8
# dtype: int64
# None
# 0    8
# dtype: int64
# 0.19887499999999997
# 4
# 0.19887499999999997
# 0.0525
# 7
# 0.0525
# 0    7
# dtype: int64
# None
# 0    7
# dtype: int64
# 0.1951
# 4
# 0.1951
# 0    6
# dtype: int64
# None
# 0    6
# dtype: int64
# 2    7
# dtype: int64
# None
# 2    7
# dtype: int64
# 0.3525
# 1
# 0.3525
# 0    5
# dtype: int64
# None
# 0    5
# dtype: int64
# 0    8
# dtype: int64
# None
# 0    8
# dtype: int64
# 0.06888571428571429
# 7
# 0.06888571428571429
# 0.09240243902439021
# 5
# 0.09240243902439021
# 0.061395833333333344
# 7
# 0.061395833333333344
# 0.3467647058823529
# 1
# 0.3467647058823529
# 0.254375
# 2
# 0.254375
# 0.32833333333333337
# 1
# 0.32833333333333337
# 0    9
# dtype: int64
# None
# 0    9
# dtype: int64
# 0.3325
# 1
# 0.3325
# 0    7
# dtype: int64
# None
# 0    7
# dtype: int64
# 0    6
# dtype: int64
# None
# 0    6
# dtype: int64
# 0.17779999999999999
# 4
# 0.17779999999999999
# 0.09
# 3
# 0.09
# 0    8
# dtype: int64
# None
# 0    8
# dtype: int64
# 0    6
# dtype: int64
# None
# 0    6
# dtype: int64
# 2    6
# dtype: int64
# None
# 2    6
# dtype: int64
# 0.07794444444444444
# 5
# 0.07794444444444444
# 0.07239999999999999
# 5
# 0.07239999999999999
# 0.3525
# 1
# 0.3525
# 0    10
# dtype: int64
# None
# 0    10
# dtype: int64
# 0    7
# dtype: int64
# None
# 0    7
# dtype: int64
# 0.265
# 2
# 0.265
# 1    5
# dtype: int64
# None
# 1    5
# dtype: int64
# 0    8
# dtype: int64
# None
# 0    8
# dtype: int64
# 0.059625
# 7
# 0.059625
# 0    6
# dtype: int64
# None
# 0    6
# dtype: int64
# 1    7
# dtype: int64
# None
# 1    7
# dtype: int64
# 0.34071428571428575
# 1
# 0.34071428571428575
# 0.034875
# 6
# 0.034875
# 0    11
# dtype: int64
# None
# 0    11
# dtype: int64
# 1    7
# dtype: int64
# None
# 1    7
# dtype: int64
# 0.35833333333333334
# 1
# 0.35833333333333334
# 0.3525
# 1
# 0.3525
# 0    7
# dtype: int64
# None
# 0    7
# dtype: int64
# 0    8
# dtype: int64
# None
# 0    8
# dtype: int64
# 0    7
# dtype: int64
# None
# 0    7
# dtype: int64
# 0.2711764705882353
# 2
# 0.2711764705882353
# 0.36
# 1
# 0.36
# 0.12925
# 5
# 0.12925
# 0.08785714285714286
# 3
# 0.08785714285714286
# 0    6
# dtype: int64
# None
# 0    6
# dtype: int64
# 0.35875
# 1
# 0.35875
# 0    7
# dtype: int64
# None
# 0    7
# dtype: int64
# 0.26833333333333337
# 2
# 0.26833333333333337
# 0    7
# dtype: int64
# None
# 0    7
# dtype: int64
# 0    6
# dtype: int64
# None
# 0    6
# dtype: int64
# 0    7
# dtype: int64
# None
# 0    7
# dtype: int64
# 2    6
# dtype: int64
# None
# 2    6
# dtype: int64
# 0.09833333333333333
# 3
# 0.09833333333333333
# 0    7
# dtype: int64
# None
# 0    7
# dtype: int64
# 0.24516666666666667
# 4
# 0.24516666666666667
# 0    6
# dtype: int64
# None
# 0    6
# dtype: int64
# 0    5
# dtype: int64
# None
# 0    5
# dtype: int64
# 0.09689655172413794
# 3
# 0.09689655172413794
# 0.22416666666666665
# 4
# 0.22416666666666665
# 0.041999999999999996
# 6
# 0.041999999999999996
# 0.079625
# 5
# 0.079625
# 0.3425
# 1
# 0.3425
# 0    6
# dtype: int64
# None
# 0    6
# dtype: int64
# 0    9
# dtype: int64
# None
# 0    9
# dtype: int64
# 0.2725
# 2
# 0.2725
# 0    7
# dtype: int64
# None
# 0    7
# dtype: int64
# 0    6
# dtype: int64
# None
# 0    6
# dtype: int64
# 0.26875000000000004
# 2
# 0.26875000000000004
# 0    8
# dtype: int64
# None
# 0    8
# dtype: int64
# 0.3633333333333333
# 1
# 0.3633333333333333
# 0    6
# dtype: int64
# None
# 0    6
# dtype: int64
# 0.3725
# 1
# 0.3725
# 0    6
# dtype: int64
# None
# 0    6
# dtype: int64
# 0    8
# dtype: int64
# None
# 0    8
# dtype: int64
# 0.26857142857142857
# 2
# 0.26857142857142857
# 0.08833333333333333
# 3
# 0.08833333333333333
# 0    6
# dtype: int64
# None
# 0    6
# dtype: int64
# 1    7
# dtype: int64
# None
# 1    7
# dtype: int64
# 3    6
# dtype: int64
# None
# 3    6
# dtype: int64
# 0.08399999999999999
# 7
# 0.08399999999999999
# 0.24710000000000001
# 4
# 0.24710000000000001
# 0.267
# 2
# 0.267
# 0.35
# 1
# 0.35
# 0    8
# dtype: int64
# None
# 0    8
# dtype: int64
# 0    9
# dtype: int64
# None
# 0    9
# dtype: int64
# 0.355
# 1
# 0.355
# 0.35
# 1
# 0.35
# 0    7
# dtype: int64
# None
# 0    7
# dtype: int64
# 0    10
# dtype: int64
# None
# 0    10
# dtype: int64
# 0    7
# dtype: int64
# None
# 0    7
# dtype: int64
# 0.10400000000000001
# 3
# 0.10400000000000001
# 0.3975
# 1
# 0.3975
# 0    5
# dtype: int64
# None
# 0    5
# dtype: int64
# 0    9
# dtype: int64
# None
# 0    9
# dtype: int64
# 0.1235
# 5
# 0.1235
# 0    6
# dtype: int64
# None
# 0    6
# dtype: int64
# 0    9
# dtype: int64
# None
# 0    9
# dtype: int64
# 0.2625
# 2
# 0.2625
# 1    7
# dtype: int64
# None
# 1    7
# dtype: int64
# 1    10
# dtype: int64
# None
# 1    10
# dtype: int64
# 2.490950226244344
# 0
# 2.490950226244344
# 1.4265734265734267
# 0
# 1.4265734265734267
# 0.15634146341463412
# 5
# 0.15634146341463412
# 0.10180851063829788
# 3
# 0.10180851063829788
# 0.09321666666666668
# 7
# 0.09321666666666668
# 0.10344117647058823
# 5
# 0.10344117647058823
# 0.3685714285714286
# 1
# 0.3685714285714286
# 0.2255
# 4
# 0.2255
# 1    9
# dtype: int64
# None
# 1    9
# dtype: int64
# 0    11
# dtype: int64
# None
# 0    11
# dtype: int64
# 0.375
# 1
# 0.375
# 0.07866666666666666
# 7
# 0.07866666666666666
# 0    7
# dtype: int64
# None
# 0    7
# dtype: int64
# 0    10
# dtype: int64
# None
# 0    10
# dtype: int64
# 0    9
# dtype: int64
# None
# 0    9
# dtype: int64
# 0.27465
# 4
# 0.27465
# 0.09583333333333334
# 3
# 0.09583333333333334
# 0.3875
# 1
# 0.3875
# 0    10
# dtype: int64
# None
# 0    10
# dtype: int64
# 0    8
# dtype: int64
# None
# 0    8
# dtype: int64
# 0.253875
# 4
# 0.253875
# 0.24966666666666668
# 4
# 0.24966666666666668
# 0    11
# dtype: int64
# None
# 0    11
# dtype: int64
# 0    8
# dtype: int64
# None
# 0    8
# dtype: int64
# 0    11
# dtype: int64
# None
# 0    11
# dtype: int64
# 0.38875
# 1
# 0.38875
# 0    9
# dtype: int64
# None
# 0    9
# dtype: int64
# 0.4125
# 1
# 0.4125
# 0    9
# dtype: int64
# None
# 0    9
# dtype: int64
# 0    6
# dtype: int64
# None
# 0    6
# dtype: int64
# 0.11046153846153846
# 7
# 0.11046153846153846
# 0.4007142857142857
# 1
# 0.4007142857142857
# 0.38000000000000006
# 1
# 0.38000000000000006
# 0.37
# 1
# 0.37
# 0    7
# dtype: int64
# None
# 0    7
# dtype: int64
# 0    5
# dtype: int64
# None
# 0    5
# dtype: int64
# 0    10
# dtype: int64
# None
# 0    10
# dtype: int64
# 0.067625
# 6
# 0.067625
# 0    11
# dtype: int64
# None
# 0    11
# dtype: int64
# 0.34016666666666673
# 4
# 0.34016666666666673
# 0    7
# dtype: int64
# None
# 0    7
# dtype: int64
# 0    9
# dtype: int64
# None
# 0    9
# dtype: int64
# 0.3316666666666667
# 2
# 0.3316666666666667
# 0.4275
# 1
# 0.4275
# 0.42
# 1
# 0.42
# 0    8
# dtype: int64
# None
# 0    8
# dtype: int64
# 0    7
# dtype: int64
# None
# 0    7
# dtype: int64
# 0.435
# 1
# 0.435
# 0    14
# dtype: int64
# None
# 0    14
# dtype: int64
# 0    8
# dtype: int64
# None
# 0    8
# dtype: int64
# 1    10
# dtype: int64
# None
# 1    10
# dtype: int64
# 0.10594117647058825
# 7
# 0.10594117647058825
# 0.386875
# 1
# 0.386875
# 0.258
# 4
# 0.258
# 0    8
# dtype: int64
# None
# 0    8
# dtype: int64
# 0.3725
# 1
# 0.3725
# 0    10
# dtype: int64
# None
# 0    10
# dtype: int64
# 0    12
# dtype: int64
# None
# 0    12
# dtype: int64
# 0.3075
# 2
# 0.3075
# 0    9
# dtype: int64
# None
# 0    9
# dtype: int64
# 0.4125
# 1
# 0.4125
# 0    11
# dtype: int64
# None
# 0    11
# dtype: int64
# 0    9
# dtype: int64
# None
# 0    9
# dtype: int64
# 0.11305555555555556
# 5
# 0.11305555555555556
# 0.42166666666666663
# 1
# 0.42166666666666663
# 0.4175
# 1
# 0.4175
# 0    12
# dtype: int64
# None
# 0    12
# dtype: int64
# 0    15
# dtype: int64
# None
# 0    15
# dtype: int64
# 0    11
# dtype: int64
# None
# 0    11
# dtype: int64
# 0.4175
# 1
# 0.4175
# 0.40166666666666667
# 1
# 0.40166666666666667
# 0.3975
# 1
# 0.3975
# 0    12
# dtype: int64
# None
# 0    12
# dtype: int64
# 0    10
# dtype: int64
# None
# 0    10
# dtype: int64
# 0    11
# dtype: int64
# None
# 0    11
# dtype: int64
# 0.33
# 2
# 0.33
# 0    18
# dtype: int64
# None
# 0    18
# dtype: int64
# 0    10
# dtype: int64
# None
# 0    10
# dtype: int64
# 0.3405714285714285
# 2
# 0.3405714285714285
# 0.19313157894736838
# 5
# 0.19313157894736838
# 0.1155
# 3
# 0.1155
# 0.4235714285714286
# 1
# 0.4235714285714286
# 0.4033333333333333
# 1
# 0.4033333333333333
# 0    6
# dtype: int64
# None
# 0    6
# dtype: int64
# 0.4125
# 1
# 0.4125
# 0    7
# dtype: int64
# None
# 0    7
# dtype: int64
# 0    8
# dtype: int64
# None
# 0    8
# dtype: int64
# 0.32125
# 2
# 0.32125
# 1    9
# dtype: int64
# None
# 1    9
# dtype: int64
# 0.33
# 2
# 0.33
# 0    7
# dtype: int64
# None
# 0    7
# dtype: int64
# 0    9
# dtype: int64
# None
# 0    9
# dtype: int64
# 2    9
# dtype: int64
# None
# 2    9
# dtype: int64
# 0.3277777777777778
# 2
# 0.3277777777777778
# 0.43
# 1
# 0.43
# 0.1175
# 3
# 0.1175
# 0    9
# dtype: int64
# None
# 0    9
# dtype: int64
# 0    8
# dtype: int64
# None
# 0    8
# dtype: int64
# 0    8
# dtype: int64
# None
# 0    8
# dtype: int64
# 0.446
# 1
# 0.446
# 1    7
# dtype: int64
# None
# 1    7
# dtype: int64
# 0.455
# 1
# 0.455
# 0.3325
# 2
# 0.3325
# 0    8
# dtype: int64
# None
# 0    8
# dtype: int64
# 0    6
# dtype: int64
# None
# 0    6
# dtype: int64
# 0    9
# dtype: int64
# None
# 0    9
# dtype: int64
# 0.36000000000000004
# 2
# 0.36000000000000004
# 0.4575
# 1
# 0.4575
# 0.441
# 1
# 0.441
# 0.43
# 1
# 0.43
# 0    7
# dtype: int64
# None
# 0    7
# dtype: int64
# 0    9
# dtype: int64
# None
# 0    9
# dtype: int64
# 0.34833333333333333
# 2
# 0.34833333333333333
# 0    15
# dtype: int64
# None
# 0    15
# dtype: int64
# 0    8
# dtype: int64
# None
# 0    8
# dtype: int64
# 0.3555555555555555
# 2
# 0.3555555555555555
# 0.46187500000000004
# 4
# 0.46187500000000004
# 0.35
# 2
# 0.35
# 0    7
# dtype: int64
# None
# 0    7
# dtype: int64
# 0    12
# dtype: int64
# None
# 0    12
# dtype: int64
# 0    8
# dtype: int64
# None
# 0    8
# dtype: int64
# 0.471
# 1
# 0.471
# 2    7
# dtype: int64
# None
# 2    7
# dtype: int64
# 0.4775
# 1
# 0.4775
# 0    7
# dtype: int64
# None
# 0    7
# dtype: int64
# 0    8
# dtype: int64
# None
# 0    8
# dtype: int64
# 0.54
# 1
# 0.54
# 0    6
# dtype: int64
# None
# 0    6
# dtype: int64
# 0    10
# dtype: int64
# None
# 0    10
# dtype: int64
# 0.08672131147540985
# 6
# 0.08672131147540985
# 0.39949999999999997
# 1
# 0.39949999999999997
# 0.29966666666666664
# 2
# 0.29966666666666664
# 0.27814285714285714
# 4
# 0.27814285714285714
# 0.37124999999999997
# 1
# 0.37124999999999997
# 0.29
# 2
# 0.29
# 1    9
# dtype: int64
# None
# 1    9
# dtype: int64
# 0    7
# dtype: int64
# None
# 0    7
# dtype: int64
# 0    10
# dtype: int64
# None
# 0    10
# dtype: int64
# 0    7
# dtype: int64
# None
# 0    7
# dtype: int64
# 0.106875
# 3
# 0.106875
# 0.10200000000000001
# 3
# 0.10200000000000001
# 0.3825
# 1
# 0.3825
# 0    8
# dtype: int64
# None
# 0    8
# dtype: int64
# 0    6
# dtype: int64
# None
# 0    6
# dtype: int64
# 0.3866666666666667
# 1
# 0.3866666666666667
# 0.3825
# 1
# 0.3825
# 0    12
# dtype: int64
# None
# 0    12
# dtype: int64
# 0    7
# dtype: int64
# None
# 0    7
# dtype: int64
# 0    12
# dtype: int64
# None
# 0    12
# dtype: int64
# 1    10
# dtype: int64
# None
# 1    10
# dtype: int64
# 0.14970000000000003
# 5
# 0.14970000000000003
# 0.10977777777777778
# 7
# 0.10977777777777778
# 0.305
# 2
# 0.305
# 1    8
# dtype: int64
# None
# 1    8
# dtype: int64
# 0    13
# dtype: int64
# None
# 0    13
# dtype: int64
# 0.35033333333333333
# 4
# 0.35033333333333333
# 0.41333333333333333
# 1
# 0.41333333333333333
# 0    10
# dtype: int64
# None
# 0    10
# dtype: int64
# 0.42
# 1
# 0.42
# 0    9
# dtype: int64
# None
# 0    9
# dtype: int64
# 0    10
# dtype: int64
# None
# 0    10
# dtype: int64
# 0.42333333333333334
# 1
# 0.42333333333333334
# 0    12
# dtype: int64
# None
# 0    12
# dtype: int64
# 0.4325
# 1
# 0.4325
# 0    11
# dtype: int64
# None
# 0    11
# dtype: int64
# 0    8
# dtype: int64
# None
# 0    8
# dtype: int64
# 0.07491666666666667
# 6
# 0.07491666666666667
# 0    9
# dtype: int64
# None
# 0    9
# dtype: int64
# 0.4275
# 1
# 0.4275
# 0.4125
# 1
# 0.4125
# 0    10
# dtype: int64
# None
# 0    10
# dtype: int64
# 0    12
# dtype: int64
# None
# 0    12
# dtype: int64
# 0.4425
# 1
# 0.4425
# 0    9
# dtype: int64
# None
# 0    9
# dtype: int64
# 0    12
# dtype: int64
# None
# 0    12
# dtype: int64
# 0.11988709677419357
# 7
# 0.11988709677419357
# 0.4052083333333332
# 4
# 0.4052083333333332
# 0.10833333333333334
# 3
# 0.10833333333333334
# 0.4
# 1
# 0.4
# 0    16
# dtype: int64
# None
# 0    16
# dtype: int64
# 0    9
# dtype: int64
# None
# 0    9
# dtype: int64
# 0.1125
# 3
# 0.1125
# 0    8
# dtype: int64
# None
# 0    8
# dtype: int64
# 0    11
# dtype: int64
# None
# 0    11
# dtype: int64
# 0.19441666666666668
# 5
# 0.19441666666666668
# 0.44
# 1
# 0.44
# 0    10
# dtype: int64
# None
# 0    10
# dtype: int64
# 0    9
# dtype: int64
# None
# 0    9
# dtype: int64
# 2    6
# dtype: int64
# None
# 2    6
# dtype: int64
# 0.12578947368421053
# 7
# 0.12578947368421053
# 0.12229999999999999
# 7
# 0.12229999999999999
# 0.11499999999999999
# 3
# 0.11499999999999999
# 0    9
# dtype: int64
# None
# 0    9
# dtype: int64
# 0.4275
# 1
# 0.4275
# 1    10
# dtype: int64
# None
# 1    10
# dtype: int64
# 0.4475
# 1
# 0.4475
# 0    8
# dtype: int64
# None
# 0    8
# dtype: int64
# 0    10
# dtype: int64
# None
# 0    10
# dtype: int64
# 0.34199999999999997
# 2
# 0.34199999999999997
# 0.44
# 1
# 0.44
# 0    11
# dtype: int64
# None
# 0    11
# dtype: int64
# 0    9
# dtype: int64
# None
# 0    9
# dtype: int64
# 0.35333333333333333
# 2
# 0.35333333333333333
# 1    13
# dtype: int64
# None
# 1    13
# dtype: int64
# 0    10
# dtype: int64
# None
# 0    10
# dtype: int64
# 0.12966666666666665
# 7
# 0.12966666666666665
# 1    7
# dtype: int64
# None
# 1    7
# dtype: int64
# 0.45285714285714285
# 1
# 0.45285714285714285
# 0.34833333333333333
# 2
# 0.34833333333333333
# 0    10
# dtype: int64
# None
# 0    10
# dtype: int64
# 1    11
# dtype: int64
# None
# 1    11
# dtype: int64
# 0.4548749999999999
# 4
# 0.4548749999999999
# 0    8
# dtype: int64
# None
# 0    8
# dtype: int64
# 0.46499999999999997
# 1
# 0.46499999999999997
# 0    13
# dtype: int64
# None
# 0    13
# dtype: int64
# 0    11
# dtype: int64
# None
# 0    11
# dtype: int64
# 0.09842642140468233
# 7
# 0.09842642140468233
# 0.08163448275862072
# 7
# 0.08163448275862072
# 0.07322222222222223
# 7
# 0.07322222222222223
# 0.28578125000000004
# 2
# 0.28578125000000004
# 0.11025999999999998
# 5
# 0.11025999999999998
# 0.22107692307692306
# 4
# 0.22107692307692306
# 0.20775
# 4
# 0.20775
# 0.08
# 3
# 0.08
# 1    8
# dtype: int64
# None
# 1    8
# dtype: int64
# 0    5
# dtype: int64
# None
# 0    5
# dtype: int64
# 0.37666666666666665
# 1
# 0.37666666666666665
# 1    7
# dtype: int64
# None
# 1    7
# dtype: int64
# 0    8
# dtype: int64
# None
# 0    8
# dtype: int64
# 0.2828571428571428
# 2
# 0.2828571428571428
# 0.37666666666666665
# 1
# 0.37666666666666665
# 0.3725
# 1
# 0.3725
# 0    11
# dtype: int64
# None
# 0    11
# dtype: int64
# 0    6
# dtype: int64
# None
# 0    6
# dtype: int64
# 0    5
# dtype: int64
# None
# 0    5
# dtype: int64
# 0.09787500000000002
# 5
# 0.09787500000000002
# 0.08833333333333333
# 3
# 0.08833333333333333
# 0    7
# dtype: int64
# None
# 0    7
# dtype: int64
# 1    6
# dtype: int64
# None
# 1    6
# dtype: int64
# 0    8
# dtype: int64
# None
# 0    8
# dtype: int64
# 0.25575000000000003
# 4
# 0.25575000000000003
# 0.28333333333333327
# 2
# 0.28333333333333327
# 1    6
# dtype: int64
# None
# 1    6
# dtype: int64
# 0.06825
# 7
# 0.06825
# 0.05183333333333332
# 6
# 0.05183333333333332
# 0    8
# dtype: int64
# None
# 0    8
# dtype: int64
# 0    6
# dtype: int64
# None
# 0    6
# dtype: int64
# 0    6
# dtype: int64
# None
# 0    6
# dtype: int64
# 0.37833333333333335
# 1
# 0.37833333333333335
# 0.37333333333333335
# 1
# 0.37333333333333335
# 0    6
# dtype: int64
# None
# 0    6
# dtype: int64
# 0.0925
# 3
# 0.0925
# 0    7
# dtype: int64
# None
# 0    7
# dtype: int64
# 0    12
# dtype: int64
# None
# 0    12
# dtype: int64
# 0.09666666666666668
# 3
# 0.09666666666666668
# 0    7
# dtype: int64
# None
# 0    7
# dtype: int64
# 0    8
# dtype: int64
# None
# 0    8
# dtype: int64
# 0.11514285714285714
# 5
# 0.11514285714285714
# 0.242125
# 4
# 0.242125
# 0    5
# dtype: int64
# None
# 0    5
# dtype: int64
# 1    6
# dtype: int64
# None
# 1    6
# dtype: int64
# 0.4066666666666667
# 1
# 0.4066666666666667
# 0    5
# dtype: int64
# None
# 0    5
# dtype: int64
# 0.4175
# 1
# 0.4175
# 0    5
# dtype: int64
# None
# 0    5
# dtype: int64
# 0    8
# dtype: int64
# None
# 0    8
# dtype: int64
# 0.0603375
# 6
# 0.0603375
# 0.07764705882352942
# 7
# 0.07764705882352942
# 0.05255555555555556
# 6
# 0.05255555555555556
# 0.29125
# 2
# 0.29125
# 0.07533333333333332
# 7
# 0.07533333333333332
# 1    6
# dtype: int64
# None
# 1    6
# dtype: int64
# 0    8
# dtype: int64
# None
# 0    8
# dtype: int64
# 0    8
# dtype: int64
# None
# 0    8
# dtype: int64
# 0.05700000000000001
# 6
# 0.05700000000000001
# 0    7
# dtype: int64
# None
# 0    7
# dtype: int64
# 0.3
# 2
# 0.3
# 0    8
# dtype: int64
# None
# 0    8
# dtype: int64
# 0    6
# dtype: int64
# None
# 0    6
# dtype: int64
# 0.1065625
# 5
# 0.1065625
# 0.381
# 1
# 0.381
# 0.365
# 1
# 0.365
# 0    7
# dtype: int64
# None
# 0    7
# dtype: int64
# 0    8
# dtype: int64
# None
# 0    8
# dtype: int64
# 0    7
# dtype: int64
# None
# 0    7
# dtype: int64
# 0.29833333333333334
# 2
# 0.29833333333333334
# 0.2925
# 2
# 0.2925
# 0    8
# dtype: int64
# None
# 0    8
# dtype: int64
# 0    7
# dtype: int64
# None
# 0    7
# dtype: int64
# 0    8
# dtype: int64
# None
# 0    8
# dtype: int64
# 0.39130434782608703
# 1
# 0.39130434782608703
# 0.07754166666666665
# 7
# 0.07754166666666665
# 5    7
# dtype: int64
# None
# 5    7
# dtype: int64
# 0.14375000000000002
# 5
# 0.14375000000000002
# 0.3833333333333333
# 1
# 0.3833333333333333
# 0    6
# dtype: int64
# None
# 0    6
# dtype: int64
# 0.3875
# 1
# 0.3875
# 0    8
# dtype: int64
# None
# 0    8
# dtype: int64
# 0    7
# dtype: int64
# None
# 0    7
# dtype: int64
# 0    7
# dtype: int64
# None
# 0    7
# dtype: int64
# 0.07854545454545454
# 7
# 0.07854545454545454
# 0.29500000000000004
# 2
# 0.29500000000000004
# 0.07033333333333334
# 6
# 0.07033333333333334
# 0    5
# dtype: int64
# None
# 0    5
# dtype: int64
# 0    6
# dtype: int64
# None
# 0    6
# dtype: int64
# 1    6
# dtype: int64
# None
# 1    6
# dtype: int64
# 0.40833333333333327
# 1
# 0.40833333333333327
# 0.2995
# 4
# 0.2995
# 1    7
# dtype: int64
# None
# 1    7
# dtype: int64
# 1    6
# dtype: int64
# None
# 1    6
# dtype: int64
# 1    7
# dtype: int64
# None
# 1    7
# dtype: int64
# 0.14174657534246576
# 5
# 0.14174657534246576
# 0.10220930232558141
# 3
# 0.10220930232558141
# 0.06134482758620689
# 6
# 0.06134482758620689
# 0.26589999999999997
# 4
# 0.26589999999999997
# 0.37749999999999995
# 1
# 0.37749999999999995
# 0.365
# 1
# 0.365
# 0    8
# dtype: int64
# None
# 0    8
# dtype: int64
# 0    10
# dtype: int64
# None
# 0    10
# dtype: int64
# 0.095
# 3
# 0.095
# 0.3
# 2
# 0.3
# 0    7
# dtype: int64
# None
# 0    7
# dtype: int64
# 0    14
# dtype: int64
# None
# 0    14
# dtype: int64
# 1    6
# dtype: int64
# None
# 1    6
# dtype: int64
# 0.09666666666666665
# 3
# 0.09666666666666665
# 0.08933333333333333
# 7
# 0.08933333333333333
# 1    6
# dtype: int64
# None
# 1    6
# dtype: int64
# 0    7
# dtype: int64
# None
# 0    7
# dtype: int64
# 0.305
# 2
# 0.305
# 2    7
# dtype: int64
# None
# 2    7
# dtype: int64
# 0    6
# dtype: int64
# None
# 0    6
# dtype: int64
# 0.08853571428571429
# 7
# 0.08853571428571429
# 0.12212500000000001
# 5
# 0.12212500000000001
# 0.109
# 5
# 0.109
# 0    7
# dtype: int64
# None
# 0    7
# dtype: int64
# 1    8
# dtype: int64
# None
# 1    8
# dtype: int64
# 0.29875
# 2
# 0.29875
# 0    7
# dtype: int64
# None
# 0    7
# dtype: int64
# 1    6
# dtype: int64
# None
# 1    6
# dtype: int64
# 0.12933333333333333
# 5
# 0.12933333333333333
# 0.40499999999999997
# 1
# 0.40499999999999997
# 0    7
# dtype: int64
# None
# 0    7
# dtype: int64
# 0    8
# dtype: int64
# None
# 0    8
# dtype: int64
# 1    7
# dtype: int64
# None
# 1    7
# dtype: int64
# 0.0914642857142857
# 7
# 0.0914642857142857
# 0.11916666666666666
# 3
# 0.11916666666666666
# 0    8
# dtype: int64
# None
# 0    8
# dtype: int64
# 0.2811666666666667
# 4
# 0.2811666666666667
# 0    6
# dtype: int64
# None
# 0    6
# dtype: int64
# 1    8
# dtype: int64
# None
# 1    8
# dtype: int64
# 0.415625
# 1
# 0.415625
# 0.11000000000000001
# 3
# 0.11000000000000001
# 0.4083333333333334
# 1
# 0.4083333333333334
# 0    8
# dtype: int64
# None
# 0    8
# dtype: int64
# 0.32
# 2
# 0.32
# 0    6
# dtype: int64
# None
# 0    6
# dtype: int64
# 0    8
# dtype: int64
# None
# 0    8
# dtype: int64
# 0.4075
# 1
# 0.4075
# 0    6
# dtype: int64
# None
# 0    6
# dtype: int64
# 0    7
# dtype: int64
# None
# 0    7
# dtype: int64
# 0.32666666666666666
# 2
# 0.32666666666666666
# 1    6
# dtype: int64
# None
# 1    6
# dtype: int64
# 0    7
# dtype: int64
# None
# 0    7
# dtype: int64
# 0.17474999999999993
# 5
# 0.17474999999999993
# 0.3141176470588235
# 2
# 0.3141176470588235
# 0.088125
# 7
# 0.088125
# 0.07025
# 6
# 0.07025
# 1    6
# dtype: int64
# None
# 1    6
# dtype: int64
# 0    7
# dtype: int64
# None
# 0    7
# dtype: int64
# 0.40124999999999994
# 1
# 0.40124999999999994
# 0    7
# dtype: int64
# None
# 0    7
# dtype: int64
# 0.33625
# 4
# 0.33625
# 0    6
# dtype: int64
# None
# 0    6
# dtype: int64
# 0    7
# dtype: int64
# None
# 0    7
# dtype: int64
# 0.09138888888888888
# 7
# 0.09138888888888888
# 0.08983333333333332
# 7
# 0.08983333333333332
# 0    8
# dtype: int64
# None
# 0    8
# dtype: int64
# 0.0728
# 6
# 0.0728
# 0    7
# dtype: int64
# None
# 0    7
# dtype: int64
# 0.41625
# 1
# 0.41625
# 0    6
# dtype: int64
# None
# 0    6
# dtype: int64
# 0.425
# 1
# 0.425
# 0    6
# dtype: int64
# None
# 0    6
# dtype: int64
# 0    7
# dtype: int64
# None
# 0    7
# dtype: int64
# 0.06783333333333334
# 6
# 0.06783333333333334
# 0    8
# dtype: int64
# None
# 0    8
# dtype: int64
# 1    7
# dtype: int64
# None
# 1    7
# dtype: int64
# 0.10038461538461538
# 3
# 0.10038461538461538
# 0.07844444444444447
# 6
# 0.07844444444444447
# 0.41375
# 1
# 0.41375
# 0.4025
# 1
# 0.4025
# 0    6
# dtype: int64
# None
# 0    6
# dtype: int64
# 0    8
# dtype: int64
# None
# 0    8
# dtype: int64
# 0    6
# dtype: int64
# None
# 0    6
# dtype: int64
# 0.0951
# 7
# 0.0951
# 1    7
# dtype: int64
# None
# 1    7
# dtype: int64
# 0.3333333333333333
# 2
# 0.3333333333333333
# 0    6
# dtype: int64
# None
# 0    6
# dtype: int64
# 0    8
# dtype: int64
# None
# 0    8
# dtype: int64
# 0.43374999999999997
# 1
# 0.43374999999999997
# 1    6
# dtype: int64
# None
# 1    6
# dtype: int64
# 0.4425
# 1
# 0.4425
# 0    6
# dtype: int64
# None
# 0    6
# dtype: int64
# 0    7
# dtype: int64
# None
# 0    7
# dtype: int64
# 0.11423701298701301
# 7
# 0.11423701298701301
# 0.3791184210526317
# 4
# 0.3791184210526317
# 0.34685555555555564
# 4
# 0.34685555555555564
# 0.1015625
# 3
# 0.1015625
# 0.106375
# 7
# 0.106375
# 0.1393
# 5
# 0.1393
# 0.0645
# 6
# 0.0645
# 1    8
# dtype: int64
# None
# 1    8
# dtype: int64
# 0    6
# dtype: int64
# None
# 0    6
# dtype: int64
# 0.425
# 1
# 0.425
# 0    10
# dtype: int64
# None
# 0    10
# dtype: int64
# 0    9
# dtype: int64
# None
# 0    9
# dtype: int64
# 0.4166666666666667
# 1
# 0.4166666666666667
# 0.4075
# 1
# 0.4075
# 0    6
# dtype: int64
# None
# 0    6
# dtype: int64
# 0    7
# dtype: int64
# None
# 0    7
# dtype: int64
# 0    7
# dtype: int64
# None
# 0    7
# dtype: int64
# 0.064875
# 6
# 0.064875
# 0.3225
# 2
# 0.3225
# 0    10
# dtype: int64
# None
# 0    10
# dtype: int64
# 0.05466666666666667
# 6
# 0.05466666666666667
# 0    7
# dtype: int64
# None
# 0    7
# dtype: int64
# 1    8
# dtype: int64
# None
# 1    8
# dtype: int64
# 0.33375000000000005
# 2
# 0.33375000000000005
# 0    7
# dtype: int64
# None
# 0    7
# dtype: int64
# 0    10
# dtype: int64
# None
# 0    10
# dtype: int64
# 0.16877586206896555
# 5
# 0.16877586206896555
# 0.15870454545454543
# 5
# 0.15870454545454543
# 0.33
# 2
# 0.33
# 0.1
# 3
# 0.1
# 2    7
# dtype: int64
# None
# 2    7
# dtype: int64
# 0    11
# dtype: int64
# None
# 0    11
# dtype: int64
# 0.4466666666666667
# 1
# 0.4466666666666667
# 0    9
# dtype: int64
# None
# 0    9
# dtype: int64
# 0.455
# 1
# 0.455
# 0    7
# dtype: int64
# None
# 0    7
# dtype: int64
# 0    9
# dtype: int64
# None
# 0    9
# dtype: int64
# 0.3639333333333334
# 4
# 0.3639333333333334
# 0.0738
# 6
# 0.0738
# 0    8
# dtype: int64
# None
# 0    8
# dtype: int64
# 1    9
# dtype: int64
# None
# 1    9
# dtype: int64
# 0.10615000000000001
# 7
# 0.10615000000000001
# 0.16235714285714284
# 5
# 0.16235714285714284
# 0.11
# 3
# 0.11
# 1    6
# dtype: int64
# None
# 1    6
# dtype: int64
# 0    7
# dtype: int64
# None
# 0    7
# dtype: int64
# 0.43166666666666664
# 1
# 0.43166666666666664
# 0.4275
# 1
# 0.4275
# 0    6
# dtype: int64
# None
# 0    6
# dtype: int64
# 0    8
# dtype: int64
# None
# 0    8
# dtype: int64
# 0    5
# dtype: int64
# None
# 0    5
# dtype: int64
# 0.43333333333333335
# 1
# 0.43333333333333335
# 0    11
# dtype: int64
# None
# 0    11
# dtype: int64
# 0.32499999999999996
# 2
# 0.32499999999999996
# 0    9
# dtype: int64
# None
# 0    9
# dtype: int64
# 0    7
# dtype: int64
# None
# 0    7
# dtype: int64
# 0.2004285714285714
# 5
# 0.2004285714285714
# 0.10333333333333333
# 3
# 0.10333333333333333
# 2    7
# dtype: int64
# None
# 2    7
# dtype: int64
# 0.1125
# 3
# 0.1125
# 0    7
# dtype: int64
# None
# 0    7
# dtype: int64
# 0    5
# dtype: int64
# None
# 0    5
# dtype: int64
# 0    8
# dtype: int64
# None
# 0    8
# dtype: int64
# 0.10951612903225812
# 3
# 0.10951612903225812
# 0.4225833333333333
# 4
# 0.4225833333333333
# 0.4414285714285714
# 1
# 0.4414285714285714
# 0.42624999999999996
# 1
# 0.42624999999999996
# 1    6
# dtype: int64
# None
# 1    6
# dtype: int64
# 0.435
# 1
# 0.435
# 0    7
# dtype: int64
# None
# 0    7
# dtype: int64
# 0    6
# dtype: int64
# None
# 0    6
# dtype: int64
# 0.46166666666666667
# 1
# 0.46166666666666667
# 0    8
# dtype: int64
# None
# 0    8
# dtype: int64
# 0    6
# dtype: int64
# None
# 0    6
# dtype: int64
# 0.1086
# 7
# 0.1086
# 0.4475
# 1
# 0.4475
# 0    6
# dtype: int64
# None
# 0    6
# dtype: int64
# 0    9
# dtype: int64
# None
# 0    9
# dtype: int64
# 0    7
# dtype: int64
# None
# 0    7
# dtype: int64
# 0.3357894736842105
# 2
# 0.3357894736842105
# 0.3279166666666667
# 2
# 0.3279166666666667
# 1    8
# dtype: int64
# None
# 1    8
# dtype: int64
# 0.11499999999999999
# 3
# 0.11499999999999999
# 0.445
# 1
# 0.445
# 0.44
# 1
# 0.44
# 1    7
# dtype: int64
# None
# 1    7
# dtype: int64
# 0    8
# dtype: int64
# None
# 0    8
# dtype: int64
# 0    8
# dtype: int64
# None
# 0    8
# dtype: int64
# 0    7
# dtype: int64
# None
# 0    7
# dtype: int64
# 0.094
# 6
# 0.094
# 2    7
# dtype: int64
# None
# 2    7
# dtype: int64
# 0.4466666666666667
# 1
# 0.4466666666666667
# 0    8
# dtype: int64
# None
# 0    8
# dtype: int64
# 0.455
# 1
# 0.455
# 0    11
# dtype: int64
# None
# 0    11
# dtype: int64
# 0    6
# dtype: int64
# None
# 0    6
# dtype: int64
# 0.11134615384615387
# 3
# 0.11134615384615387
# 0.3397777777777779
# 2
# 0.3397777777777779
# 0.11861764705882354
# 7
# 0.11861764705882354
# 0.0624375
# 6
# 0.0624375
# 0    7
# dtype: int64
# None
# 0    7
# dtype: int64
# 0.3423333333333334
# 4
# 0.3423333333333334
# 0.41333333333333333
# 1
# 0.41333333333333333
# 0    11
# dtype: int64
# None
# 0    11
# dtype: int64
# 1    8
# dtype: int64
# None
# 1    8
# dtype: int64
# 0.44
# 1
# 0.44
# 0    7
# dtype: int64
# None
# 0    7
# dtype: int64
# 0.4475
# 1
# 0.4475
# 0    8
# dtype: int64
# None
# 0    8
# dtype: int64
# 0    7
# dtype: int64
# None
# 0    7
# dtype: int64
# 0.10444444444444444
# 3
# 0.10444444444444444
# 0.4275
# 1
# 0.4275
# 0    8
# dtype: int64
# None
# 0    8
# dtype: int64
# 0    7
# dtype: int64
# None
# 0    7
# dtype: int64
# 0.12057142857142857
# 7
# 0.12057142857142857
# 0.08975
# 6
# 0.08975
# 0.10800000000000001
# 3
# 0.10800000000000001
# 1    9
# dtype: int64
# None
# 1    9
# dtype: int64
# 0.425
# 1
# 0.425
# 0    9
# dtype: int64
# None
# 0    9
# dtype: int64
# 1    7
# dtype: int64
# None
# 1    7
# dtype: int64
# 0    7
# dtype: int64
# None
# 0    7
# dtype: int64
# 0    10
# dtype: int64
# None
# 0    10
# dtype: int64
# 0.4585714285714285
# 1
# 0.4585714285714285
# 0.08675000000000001
# 6
# 0.08675000000000001
# 5    8
# dtype: int64
# None
# 5    8
# dtype: int64
# 0.191375
# 5
# 0.191375
# 0    13
# dtype: int64
# None
# 0    13
# dtype: int64
# 0    8
# dtype: int64
# None
# 0    8
# dtype: int64
# 0.47031249999999997
# 1
# 0.47031249999999997
# 0.12304999999999999
# 7
# 0.12304999999999999
# 0.0863
# 6
# 0.0863
# 1    8
# dtype: int64
# None
# 1    8
# dtype: int64
# 1    7
# dtype: int64
# None
# 1    7
# dtype: int64
# 0.461
# 1
# 0.461
# 0.34875
# 2
# 0.34875
# 1    7
# dtype: int64
# None
# 1    7
# dtype: int64
# 0.3525
# 2
# 0.3525
# 0    9
# dtype: int64
# None
# 0    9
# dtype: int64
# 0    7
# dtype: int64
# None
# 0    7
# dtype: int64
# 0    9
# dtype: int64
# None
# 0    9
# dtype: int64
# 0.21108333333333337
# 5
# 0.21108333333333337
# 0.355
# 2
# 0.355
# 0.3525
# 2
# 0.3525
# 0    6
# dtype: int64
# None
# 0    6
# dtype: int64
# 0    8
# dtype: int64
# None
# 0    8
# dtype: int64
# 0    8
# dtype: int64
# None
# 0    8
# dtype: int64
# 0.49333333333333335
# 1
# 0.49333333333333335
# 1    7
# dtype: int64
# None
# 1    7
# dtype: int64
# 0    10
# dtype: int64
# None
# 0    10
# dtype: int64
# 0.12327272727272728
# 7
# 0.12327272727272728
# 0.09687500000000003
# 6
# 0.09687500000000003
# 0.12125
# 3
# 0.12125
# 0.3441666666666667
# 2
# 0.3441666666666667
# 0.44
# 1
# 0.44
# 0    6
# dtype: int64
# None
# 0    6
# dtype: int64
# 0    8
# dtype: int64
# None
# 0    8
# dtype: int64
# 0.45999999999999996
# 1
# 0.45999999999999996
# 0    7
# dtype: int64
# None
# 0    7
# dtype: int64
# 0.4725
# 1
# 0.4725
# 0    8
# dtype: int64
# None
# 0    8
# dtype: int64
# 0    7
# dtype: int64
# None
# 0    7
# dtype: int64
# 0.3475
# 2
# 0.3475
# 0    14
# dtype: int64
# None
# 0    14
# dtype: int64
# 0    6
# dtype: int64
# None
# 0    6
# dtype: int64
# 0.34687500000000004
# 2
# 0.34687500000000004
# 0.11666666666666665
# 7
# 0.11666666666666665
# 0    9
# dtype: int64
# None
# 0    9
# dtype: int64
# 0    6
# dtype: int64
# None
# 0    6
# dtype: int64
# 0.1135
# 6
# 0.1135
# 1    7
# dtype: int64
# None
# 1    7
# dtype: int64
# 0.4633333333333333
# 1
# 0.4633333333333333
# 0.36
# 2
# 0.36
# 0    13
# dtype: int64
# None
# 0    13
# dtype: int64
# 0    7
# dtype: int64
# None
# 0    7
# dtype: int64
# 0    6
# dtype: int64
# None
# 0    6
# dtype: int64
# 0.4588235294117647
# 1
# 0.4588235294117647
# 0.125
# 3
# 0.125
# 0.446875
# 1
# 0.446875
# 0.12
# 3
# 0.12
# 0.11833333333333333
# 3
# 0.11833333333333333
# 0    6
# dtype: int64
# None
# 0    6
# dtype: int64
# 0    7
# dtype: int64
# None
# 0    7
# dtype: int64
# 0    8
# dtype: int64
# None
# 0    8
# dtype: int64
# 0.4525
# 1
# 0.4525
# 0    8
# dtype: int64
# None
# 0    8
# dtype: int64
# 0.35750000000000004
# 2
# 0.35750000000000004
# 0    8
# dtype: int64
# None
# 0    8
# dtype: int64
# 0    6
# dtype: int64
# None
# 0    6
# dtype: int64
# 0.445
# 1
# 0.445
# 0.4425
# 1
# 0.4425
# 0    12
# dtype: int64
# None
# 0    12
# dtype: int64
# 0    7
# dtype: int64
# None
# 0    7
# dtype: int64
# 0    16
# dtype: int64
# None
# 0    16
# dtype: int64
# 0    8
# dtype: int64
# None
# 0    8
# dtype: int64
# 0.18623109243697492
# 7
# 0.18623109243697492
# 0.24483597285067873
# 5
# 0.24483597285067873
# 2.1875
# 0
# 2.1875
# 0.12511538461538466
# 3
# 0.12511538461538466
# 0.4613924050632914
# 1
# 0.4613924050632914
# 1.5227272727272727
# 0
# 1.5227272727272727
# 0.1504285714285714
# 7
# 0.1504285714285714
# 0.09650000000000002
# 6
# 0.09650000000000002
# 0.4144
# 4
# 0.4144
# 0.435
# 1
# 0.435
# 0.4275
# 1
# 0.4275
# 0    9
# dtype: int64
# None
# 0    9
# dtype: int64
# 0    10
# dtype: int64
# None
# 0    10
# dtype: int64
# 0    9
# dtype: int64
# None
# 0    9
# dtype: int64
# 0    8
# dtype: int64
# None
# 0    8
# dtype: int64
# 0.45166666666666666
# 4
# 0.45166666666666666
# 0.13975
# 7
# 0.13975
# 0.4525
# 1
# 0.4525
# 0    7
# dtype: int64
# None
# 0    7
# dtype: int64
# 0    12
# dtype: int64
# None
# 0    12
# dtype: int64
# 0    11
# dtype: int64
# None
# 0    11
# dtype: int64
# 0.4525
# 1
# 0.4525
# 0    8
# dtype: int64
# None
# 0    8
# dtype: int64
# 0    15
# dtype: int64
# None
# 0    15
# dtype: int64
# 0.16150000000000003
# 7
# 0.16150000000000003
# 0.4516666666666667
# 1
# 0.4516666666666667
# 0    10
# dtype: int64
# None
# 0    10
# dtype: int64
# 0.4583333333333333
# 1
# 0.4583333333333333
# 0    11
# dtype: int64
# None
# 0    11
# dtype: int64
# 0    10
# dtype: int64
# None
# 0    10
# dtype: int64
# 0.35375
# 2
# 0.35375
# 0.3466666666666667
# 2
# 0.3466666666666667
# 0    10
# dtype: int64
# None
# 0    10
# dtype: int64
# 0    9
# dtype: int64
# None
# 0    9
# dtype: int64
# 0    7
# dtype: int64
# None
# 0    7
# dtype: int64
# 0.45841304347826084
# 4
# 0.45841304347826084
# 0.44181818181818183
# 1
# 0.44181818181818183
# 0.33599999999999997
# 2
# 0.33599999999999997
# 0.33
# 2
# 0.33
# 0    8
# dtype: int64
# None
# 0    8
# dtype: int64
# 0    13
# dtype: int64
# None
# 0    13
# dtype: int64
# 1    7
# dtype: int64
# None
# 1    7
# dtype: int64
# 0.12
# 3
# 0.12
# 0.1175
# 3
# 0.1175
# 0    13
# dtype: int64
# None
# 0    13
# dtype: int64
# 0.17900000000000002
# 5
# 0.17900000000000002
# 1    9
# dtype: int64
# None
# 1    9
# dtype: int64
# 0    7
# dtype: int64
# None
# 0    7
# dtype: int64
# 0.4525
# 1
# 0.4525
# 0    11
# dtype: int64
# None
# 0    11
# dtype: int64
# 0    16
# dtype: int64
# None
# 0    16
# dtype: int64
# 0.45
# 1
# 0.45
# 0.11785714285714285
# 3
# 0.11785714285714285
# 0.35333333333333333
# 2
# 0.35333333333333333
# 0    12
# dtype: int64
# None
# 0    12
# dtype: int64
# 0.3575
# 2
# 0.3575
# 0    8
# dtype: int64
# None
# 0    8
# dtype: int64
# 0    9
# dtype: int64
# None
# 0    9
# dtype: int64
# 0.43875
# 1
# 0.43875
# 0.4275
# 1
# 0.4275
# 0    10
# dtype: int64
# None
# 0    10
# dtype: int64
# 0    9
# dtype: int64
# None
# 0    9
# dtype: int64
# 0.503
# 4
# 0.503
# 0    13
# dtype: int64
# None
# 0    13
# dtype: int64
# 0    10
# dtype: int64
# None
# 0    10
# dtype: int64
# 0.369
# 2
# 0.369
# 0    8
# dtype: int64
# None
# 0    8
# dtype: int64
# 0.4583333333333333
# 1
# 0.4583333333333333
# 0    9
# dtype: int64
# None
# 0    9
# dtype: int64
# 1    7
# dtype: int64
# None
# 1    7
# dtype: int64
# 1.4857142857142858
# 0
# 1.4857142857142858
# 0.2098333333333333
# 5
# 0.2098333333333333
# 0.3655555555555556
# 2
# 0.3655555555555556
# 0.466
# 1
# 0.466
# 0.1075
# 3
# 0.1075
# 0.0925
# 3
# 0.0925
# 0    11
# dtype: int64
# None
# 0    11
# dtype: int64
# 0    9
# dtype: int64
# None
# 0    9
# dtype: int64
# 0    11
# dtype: int64
# None
# 0    11
# dtype: int64
# 0    8
# dtype: int64
# None
# 0    8
# dtype: int64
# 0.0905
# 6
# 0.0905
# 0.4775
# 1
# 0.4775
# 0    8
# dtype: int64
# None
# 0    8
# dtype: int64
# 0    12
# dtype: int64
# None
# 0    12
# dtype: int64
# 1    10
# dtype: int64
# None
# 1    10
# dtype: int64
# 0.5299444444444444
# 4
# 0.5299444444444444
# 0.48
# 1
# 0.48
# 0    8
# dtype: int64
# None
# 0    8
# dtype: int64
# 0    7
# dtype: int64
# None
# 0    7
# dtype: int64
# 0.5528000000000001
# 4
# 0.5528000000000001
# 2    9
# dtype: int64
# None
# 2    9
# dtype: int64
# 0    8
# dtype: int64
# None
# 0    8
# dtype: int64
# 0.11617647058823531
# 3
# 0.11617647058823531
# 0.11055555555555556
# 3
# 0.11055555555555556
# 0.48500000000000004
# 1
# 0.48500000000000004
# 0.4775
# 1
# 0.4775
# 0    8
# dtype: int64
# None
# 0    8
# dtype: int64
# 0    9
# dtype: int64
# None
# 0    9
# dtype: int64
# 0    17
# dtype: int64
# None
# 0    17
# dtype: int64
# 0.51175
# 4
# 0.51175
# 0.47
# 1
# 0.47
# 0.4675
# 1
# 0.4675
# 0    9
# dtype: int64
# None
# 0    9
# dtype: int64
# 0    8
# dtype: int64
# None
# 0    8
# dtype: int64
# 0    11
# dtype: int64
# None
# 0    11
# dtype: int64
# 0.17833333333333332
# 7
# 0.17833333333333332
# 0    9
# dtype: int64
# None
# 0    9
# dtype: int64
# 0    11
# dtype: int64
# None
# 0    11
# dtype: int64
# 0.37437499999999996
# 2
# 0.37437499999999996
# 0.47000000000000003
# 1
# 0.47000000000000003
# 0.36166666666666664
# 2
# 0.36166666666666664
# 1    10
# dtype: int64
# None
# 1    10
# dtype: int64
# 0    9
# dtype: int64
# None
# 0    9
# dtype: int64
# 0    9
# dtype: int64
# None
# 0    9
# dtype: int64
# 0.485
# 1
# 0.485
# 0    10
# dtype: int64
# None
# 0    10
# dtype: int64
# 0.495
# 1
# 0.495
# 0    11
# dtype: int64
# None
# 0    11
# dtype: int64
# 0    10
# dtype: int64
# None
# 0    10
# dtype: int64
# 0.3666666666666668
# 2
# 0.3666666666666668
# 0.11089130434782608
# 6
# 0.11089130434782608
# 0.13944444444444445
# 3
# 0.13944444444444445
# 1.4
# 0
# 1.4
# 0.13333333333333333
# 3
# 0.13333333333333333
# 0    8
# dtype: int64
# None
# 0    8
# dtype: int64
# 0    13
# dtype: int64
# None
# 0    13
# dtype: int64
# 0.4525
# 1
# 0.4525
# 0    8
# dtype: int64
# None
# 0    8
# dtype: int64
# 0    18
# dtype: int64
# None
# 0    18
# dtype: int64
# 1.5
# 0
# 1.5
# 0.445
# 1
# 0.445
# 0    16
# dtype: int64
# None
# 0    16
# dtype: int64
# 0    14
# dtype: int64
# None
# 0    14
# dtype: int64
# 0    12
# dtype: int64
# None
# 0    12
# dtype: int64
# 0.46035714285714285
# 1
# 0.46035714285714285
# 0.4511111111111112
# 1
# 0.4511111111111112
# 0.49699999999999994
# 4
# 0.49699999999999994
# 1.5
# 0
# 1.5
# 0.3425
# 2
# 0.3425
# 0    11
# dtype: int64
# None
# 0    11
# dtype: int64
# 0    8
# dtype: int64
# None
# 0    8
# dtype: int64
# 0    11
# dtype: int64
# None
# 0    11
# dtype: int64
# 0    13
# dtype: int64
# None
# 0    13
# dtype: int64
# 0.1366666666666667
# 3
# 0.1366666666666667
# 0    11
# dtype: int64
# None
# 0    11
# dtype: int64
# 0    10
# dtype: int64
# None
# 0    10
# dtype: int64
# 0.477
# 1
# 0.477
# 1    10
# dtype: int64
# None
# 1    10
# dtype: int64
# 0.49
# 1
# 0.49
# 0    8
# dtype: int64
# None
# 0    8
# dtype: int64
# 0    9
# dtype: int64
# None
# 0    9
# dtype: int64
# 0.21417857142857136
# 5
# 0.21417857142857136
# 0.48416666666666663
# 1
# 0.48416666666666663
# 0.5171428571428571
# 4
# 0.5171428571428571
# 0.15
# 3
# 0.15
# 0    12
# dtype: int64
# None
# 0    12
# dtype: int64
# 0    9
# dtype: int64
# None
# 0    9
# dtype: int64
# 0.475
# 1
# 0.475
# 0.3725
# 2
# 0.3725
# 0    7
# dtype: int64
# None
# 0    7
# dtype: int64
# 0    8
# dtype: int64
# None
# 0    8
# dtype: int64
# 0    14
# dtype: int64
# None
# 0    14
# dtype: int64
# 0.5
# 1
# 0.5
# 0.49
# 1
# 0.49
# 1    10
# dtype: int64
# None
# 1    10
# dtype: int64
# 0    9
# dtype: int64
# None
# 0    9
# dtype: int64
# 1    9
# dtype: int64
# None
# 1    9
# dtype: int64
# 0.5848437499999999
# 4
# 0.5848437499999999
# 0.12694444444444444
# 6
# 0.12694444444444444
# 0.38
# 2
# 0.38
# 1.5
# 0
# 1.5
# 0.47
# 1
# 0.47
# 0    9
# dtype: int64
# None
# 0    9
# dtype: int64
# 0    12
# dtype: int64
# None
# 0    12
# dtype: int64
# 0.505
# 1
# 0.505
# 0    9
# dtype: int64
# None
# 0    9
# dtype: int64
# 0    8
# dtype: int64
# None
# 0    8
# dtype: int64
# 0    21
# dtype: int64
# None
# 0    21
# dtype: int64
# 0.17250000000000001
# 7
# 0.17250000000000001
# 0    12
# dtype: int64
# None
# 0    12
# dtype: int64
# 0    13
# dtype: int64
# None
# 0    13
# dtype: int64
# 0.6229285714285714
# 4
# 0.6229285714285714
# 0.38666666666666666
# 2
# 0.38666666666666666
# 1.6666666666666667
# 0
# 1.6666666666666667
# 0    8
# dtype: int64
# None
# 0    8
# dtype: int64
# 0    15
# dtype: int64
# None
# 0    15
# dtype: int64
# 1.6666666666666667
# 0
# 1.6666666666666667
# 0    15
# dtype: int64
# None
# 0    15
# dtype: int64
# 0.4975
# 1
# 0.4975
# 0    12
# dtype: int64
# None
# 0    12
# dtype: int64
# 0    11
# dtype: int64
# None
# 0    11
# dtype: int64
# 0    9
# dtype: int64
# None
# 0    9
# dtype: int64
# 0.20159090909090904
# 5
# 0.20159090909090904
# 0.1506764705882353
# 7
# 0.1506764705882353
# 0.4621875
# 1
# 0.4621875
# 0.4139285714285714
# 4
# 0.4139285714285714
# 0.0688
# 6
# 0.0688
# 0.4066666666666667
# 1
# 0.4066666666666667
# 0    8
# dtype: int64
# None
# 0    8
# dtype: int64
# 0.4325
# 1
# 0.4325
# 0    14
# dtype: int64
# None
# 0    14
# dtype: int64
# 0    12
# dtype: int64
# None
# 0    12
# dtype: int64
# 0    8
# dtype: int64
# None
# 0    8
# dtype: int64
# 0.4452222222222222
# 4
# 0.4452222222222222
# 0.357
# 2
# 0.357
# 0.345
# 2
# 0.345
# 0    7
# dtype: int64
# None
# 0    7
# dtype: int64
# 0    8
# dtype: int64
# None
# 0    8
# dtype: int64
# 2    9
# dtype: int64
# None
# 2    9
# dtype: int64
# 0.12125
# 3
# 0.12125
# ...
# dtype: int64
# 0    9
# dtype: int64
# None
# 0    9
# dtype: int64
# 0.63
# 1
# 0.63
# 0    20
# dtype: int64
# None
# 0    20
# dtype: int64
# 1    16
# dtype: int64
# None
# 1    16
# dtype: int64
# 0.6125625
# 5
# 0.6125625
# 0.5806250000000001
# 5
# 0.5806250000000001
# 0    11
# dtype: int64
# None
# 0    11
# dtype: int64
# 2    10
# dtype: int64
# None
# 2    10
# dtype: int64
# 1.5
# 0
# 1.5
# 0.6575
# 1
# 0.6575
# 0    17
# dtype: int64
# None
# 0    17
# dtype: int64
# 0    9
# dtype: int64
# None
# 0    9
# dtype: int64
# 0.6575
# 1
# 0.6575
# 0    12
# dtype: int64
# None
# 0    12
# dtype: int64
# 0    11
# dtype: int64
# None
# 0    11
# dtype: int64
# 1.5593124999999999
# 4
# 1.5593124999999999
# 1.4939
# 4
# 1.4939
# 0    14
# dtype: int64
# None
# 0    14
# dtype: int64
# 0.685
# 1
# 0.685
# 0.6675
# 1
# 0.6675
# 0    17
# dtype: int64
# None
# 0    17
# dtype: int64
# 0    15
# dtype: int64
# None
# 0    15
# dtype: int64
# 1    15
# dtype: int64
# None
# 1    15
# dtype: int64
# 1.6666666666666667
# 0
# 1.6666666666666667
# 0    14
# dtype: int64
# None
# 0    14
# dtype: int64
# 0.7175
# 1
# 0.7175
# 0    13
# dtype: int64
# None
# 0    13
# dtype: int64
# 0    10
# dtype: int64
# None
# 0    10
# dtype: int64
# 0.6345277777777777
# 7
# 0.6345277777777777
# 0.5842727272727273
# 5
# 0.5842727272727273
# 1.6
# 0
# 1.6
# 0.6599999999999999
# 1
# 0.6599999999999999
# 0    17
# dtype: int64
# None
# 0    17
# dtype: int64
# 0    24
# dtype: int64
# None
# 0    24
# dtype: int64
# 0.6916666666666668
# 1
# 0.6916666666666668
# 0    16
# dtype: int64
# None
# 0    16
# dtype: int64
# 0    14
# dtype: int64
# None
# 0    14
# dtype: int64
# 1.7060000000000002
# 4
# 1.7060000000000002
# 2.0
# 0
# 2.0
# 0    15
# dtype: int64
# None
# 0    15
# dtype: int64
# 0    18
# dtype: int64
# None
# 0    18
# dtype: int64
# 0.7000000000000001
# 1
# 0.7000000000000001
# 1.6666666666666667
# 0
# 1.6666666666666667
# 0    19
# dtype: int64
# None
# 0    19
# dtype: int64
# 0.69
# 1
# 0.69
# 0    19
# dtype: int64
# None
# 0    19
# dtype: int64
# 0    13
# dtype: int64
# None
# 0    13
# dtype: int64
# 0    17
# dtype: int64
# None
# 0    17
# dtype: int64
# 0.5428571428571428
# 2
# 0.5428571428571428
# 1.3333333333333333
# 0
# 1.3333333333333333
# 0.64
# 1
# 0.64
# 0    18
# dtype: int64
# None
# 0    18
# dtype: int64
# 0    11
# dtype: int64
# None
# 0    11
# dtype: int64
# 0    21
# dtype: int64
# None
# 0    21
# dtype: int64
# 0.608375
# 5
# 0.608375
# 1    16
# dtype: int64
# None
# 1    16
# dtype: int64
# 0.7025
# 1
# 0.7025
# 0    20
# dtype: int64
# None
# 0    20
# dtype: int64
# 0    18
# dtype: int64
# None
# 0    18
# dtype: int64
# 0.4820286259541984
# 7
# 0.4820286259541984
# 0.5331210191082806
# 2
# 0.5331210191082806
# 0.409035294117647
# 7
# 0.409035294117647
# 0.3311363636363636
# 6
# 0.3311363636363636
# 0.39039130434782615
# 7
# 0.39039130434782615
# 0.6955909090909091
# 5
# 0.6955909090909091
# 0.17714285714285719
# 3
# 0.17714285714285719
# 0.508
# 2
# 0.508
# 0.63
# 1
# 0.63
# 0    10
# dtype: int64
# None
# 0    10
# dtype: int64
# 0    12
# dtype: int64
# None
# 0    12
# dtype: int64
# 1    10
# dtype: int64
# None
# 1    10
# dtype: int64
# 0.625
# 1
# 0.625
# 0    8
# dtype: int64
# None
# 0    8
# dtype: int64
# 0    10
# dtype: int64
# None
# 0    10
# dtype: int64
# 0.26325
# 6
# 0.26325
# 0    12
# dtype: int64
# None
# 0    12
# dtype: int64
# 1    9
# dtype: int64
# None
# 1    9
# dtype: int64
# 0.4019583333333334
# 7
# 0.4019583333333334
# 0.17928571428571427
# 3
# 0.17928571428571427
# 0.5216666666666666
# 2
# 0.5216666666666666
# 0    10
# dtype: int64
# None
# 0    10
# dtype: int64
# 0    11
# dtype: int64
# None
# 0    11
# dtype: int64
# 0.67125
# 1
# 0.67125
# 0.6616666666666667
# 1
# 0.6616666666666667
# 1    10
# dtype: int64
# None
# 1    10
# dtype: int64
# 0    12
# dtype: int64
# None
# 0    12
# dtype: int64
# 0    9
# dtype: int64
# None
# 0    9
# dtype: int64
# 1.4
# 0
# 1.4
# 0    11
# dtype: int64
# None
# 0    11
# dtype: int64
# 0.6525000000000001
# 1
# 0.6525000000000001
# 0    11
# dtype: int64
# None
# 0    11
# dtype: int64
# 0    12
# dtype: int64
# None
# 0    12
# dtype: int64
# 0.7220781250000001
# 5
# 0.7220781250000001
# 1.549058823529412
# 4
# 1.549058823529412
# 0.6525000000000001
# 1
# 0.6525000000000001
# 0.6880000000000001
# 5
# 0.6880000000000001
# 1.5
# 0
# 1.5
# 0    11
# dtype: int64
# None
# 0    11
# dtype: int64
# 0.635
# 1
# 0.635
# 0    11
# dtype: int64
# None
# 0    11
# dtype: int64
# 0    9
# dtype: int64
# None
# 0    9
# dtype: int64
# 1.6666666666666667
# 0
# 1.6666666666666667
# 0    9
# dtype: int64
# None
# 0    9
# dtype: int64
# 0    13
# dtype: int64
# None
# 0    13
# dtype: int64
# 1.6666666666666667
# 0
# 1.6666666666666667
# 0    10
# dtype: int64
# None
# 0    10
# dtype: int64
# 0    11
# dtype: int64
# None
# 0    11
# dtype: int64
# 1.5714285714285714
# 0
# 1.5714285714285714
# 0.51625
# 2
# 0.51625
# 0.6475
# 1
# 0.6475
# 0    14
# dtype: int64
# None
# 0    14
# dtype: int64
# 0    11
# dtype: int64
# None
# 0    11
# dtype: int64
# 0.66
# 1
# 0.66
# 0    8
# dtype: int64
# None
# 0    8
# dtype: int64
# 0    13
# dtype: int64
# None
# 0    13
# dtype: int64
# 0.6805
# 5
# 0.6805
# 0    11
# dtype: int64
# None
# 0    11
# dtype: int64
# 0    18
# dtype: int64
# None
# 0    18
# dtype: int64
# 1.4
# 0
# 1.4
# 0.6638888888888889
# 1
# 0.6638888888888889
# 0.65375
# 1
# 0.65375
# 0.6475
# 1
# 0.6475
# 0    14
# dtype: int64
# None
# 0    14
# dtype: int64
# 0    11
# dtype: int64
# None
# 0    11
# dtype: int64
# 0.5225
# 2
# 0.5225
# 0    9
# dtype: int64
# None
# 0    9
# dtype: int64
# 0    10
# dtype: int64
# None
# 0    10
# dtype: int64
# 0.6719999999999999
# 1
# 0.6719999999999999
# 0.6683333333333333
# 1
# 0.6683333333333333
# 0    11
# dtype: int64
# None
# 0    11
# dtype: int64
# 1    9
# dtype: int64
# None
# 1    9
# dtype: int64
# 1    11
# dtype: int64
# None
# 1    11
# dtype: int64
# 0.6666666666666666
# 1
# 0.6666666666666666
# 1    10
# dtype: int64
# None
# 1    10
# dtype: int64
# 0.6875
# 1
# 0.6875
# 0    10
# dtype: int64
# None
# 0    10
# dtype: int64
# 0    9
# dtype: int64
# None
# 0    9
# dtype: int64
# 0.7700500000000001
# 5
# 0.7700500000000001
# 0.6652941176470589
# 1
# 0.6652941176470589
# 0.18722222222222223
# 3
# 0.18722222222222223
# 0.5166666666666667
# 2
# 0.5166666666666667
# 0    11
# dtype: int64
# None
# 0    11
# dtype: int64
# 1.3333333333333333
# 0
# 1.3333333333333333
# 0.645
# 1
# 0.645
# 0    11
# dtype: int64
# None
# 0    11
# dtype: int64
# 0    10
# dtype: int64
# None
# 0    10
# dtype: int64
# 0    14
# dtype: int64
# None
# 0    14
# dtype: int64
# 1.3333333333333333
# 0
# 1.3333333333333333
# 0.5225
# 2
# 0.5225
# 0    15
# dtype: int64
# None
# 0    15
# dtype: int64
# 0    13
# dtype: int64
# None
# 0    13
# dtype: int64
# 0    19
# dtype: int64
# None
# 0    19
# dtype: int64
# 0.3594375
# 6
# 0.3594375
# 0.19
# 3
# 0.19
# 1    12
# dtype: int64
# None
# 1    12
# dtype: int64
# 1.5
# 0
# 1.5
# 0    9
# dtype: int64
# None
# 0    9
# dtype: int64
# 0    11
# dtype: int64
# None
# 0    11
# dtype: int64
# 1.61375
# 4
# 1.61375
# 1    10
# dtype: int64
# None
# 1    10
# dtype: int64
# 0    11
# dtype: int64
# None
# 0    11
# dtype: int64
# 1.4615384615384615
# 0
# 1.4615384615384615
# 0.9150714285714285
# 5
# 0.9150714285714285
# 2    10
# dtype: int64
# None
# 2    10
# dtype: int64
# 0.44575
# 7
# 0.44575
# 0.6475
# 1
# 0.6475
# 0    9
# dtype: int64
# None
# 0    9
# dtype: int64
# 0    10
# dtype: int64
# None
# 0    10
# dtype: int64
# 1    12
# dtype: int64
# None
# 1    12
# dtype: int64
# 0.18583333333333332
# 3
# 0.18583333333333332
# 0.63875
# 1
# 0.63875
# 0    9
# dtype: int64
# None
# 0    9
# dtype: int64
# 0.8006666666666667
# 5
# 0.8006666666666667
# 1    12
# dtype: int64
# None
# 1    12
# dtype: int64
# 0    9
# dtype: int64
# None
# 0    9
# dtype: int64
# 0.6799999999999999
# 1
# 0.6799999999999999
# 0    10
# dtype: int64
# None
# 0    10
# dtype: int64
# 0    13
# dtype: int64
# None
# 0    13
# dtype: int64
# 0.4405555555555556
# 7
# 0.4405555555555556
# 1.6736756756756759
# 4
# 1.6736756756756759
# 0.67925
# 1
# 0.67925
# 0.6588888888888889
# 1
# 0.6588888888888889
# 0.652
# 1
# 0.652
# 0.5666666666666665
# 2
# 0.5666666666666665
# 0.5549999999999999
# 2
# 0.5549999999999999
# 0    16
# dtype: int64
# None
# 0    16
# dtype: int64
# 0    12
# dtype: int64
# None
# 0    12
# dtype: int64
# 0    11
# dtype: int64
# None
# 0    11
# dtype: int64
# 0    11
# dtype: int64
# None
# 0    11
# dtype: int64
# 0.5487500000000001
# 2
# 0.5487500000000001
# 1.5
# 0
# 1.5
# 0    10
# dtype: int64
# None
# 0    10
# dtype: int64
# 0    12
# dtype: int64
# None
# 0    12
# dtype: int64
# 0    13
# dtype: int64
# None
# 0    13
# dtype: int64
# 0.3268636363636364
# 6
# 0.3268636363636364
# 0.545
# 2
# 0.545
# 1    10
# dtype: int64
# None
# 1    10
# dtype: int64
# 0.7528333333333334
# 5
# 0.7528333333333334
# 1    13
# dtype: int64
# None
# 1    13
# dtype: int64
# 0    9
# dtype: int64
# None
# 0    9
# dtype: int64
# 1.59225
# 4
# 1.59225
# 1.6666666666666667
# 0
# 1.6666666666666667
# 0    10
# dtype: int64
# None
# 0    10
# dtype: int64
# 1    9
# dtype: int64
# None
# 1    9
# dtype: int64
# 0    11
# dtype: int64
# None
# 0    11
# dtype: int64
# 0.38158823529411773
# 6
# 0.38158823529411773
# 0.3617222222222223
# 6
# 0.3617222222222223
# 1    10
# dtype: int64
# None
# 1    10
# dtype: int64
# 0.7078571428571429
# 1
# 0.7078571428571429
# 0.5516666666666667
# 2
# 0.5516666666666667
# 0    11
# dtype: int64
# None
# 0    11
# dtype: int64
# 0    10
# dtype: int64
# None
# 0    10
# dtype: int64
# 3    11
# dtype: int64
# None
# 3    11
# dtype: int64
# 0.7049999999999998
# 1
# 0.7049999999999998
# 1.3333333333333333
# 0
# 1.3333333333333333
# 0.685
# 1
# 0.685
# 0    13
# dtype: int64
# None
# 0    13
# dtype: int64
# 0    8
# dtype: int64
# None
# 0    8
# dtype: int64
# 0    10
# dtype: int64
# None
# 0    10
# dtype: int64
# 0.715
# 1
# 0.715
# 2    10
# dtype: int64
# None
# 2    10
# dtype: int64
# 0.725
# 1
# 0.725
# 0    11
# dtype: int64
# None
# 0    11
# dtype: int64
# 0    10
# dtype: int64
# None
# 0    10
# dtype: int64
# 0.5561428571428573
# 2
# 0.5561428571428573
# 0.46221052631578946
# 7
# 0.46221052631578946
# 0.4537000000000001
# 7
# 0.4537000000000001
# 0.34958333333333336
# 6
# 0.34958333333333336
# 0    11
# dtype: int64
# None
# 0    11
# dtype: int64
# 0.7066666666666667
# 1
# 0.7066666666666667
# 0    13
# dtype: int64
# None
# 0    13
# dtype: int64
# 0    11
# dtype: int64
# None
# 0    11
# dtype: int64
# 0.7753749999999999
# 5
# 0.7753749999999999
# 1.5
# 0
# 1.5
# 0    13
# dtype: int64
# None
# 0    13
# dtype: int64
# 0    12
# dtype: int64
# None
# 0    12
# dtype: int64
# 1    9
# dtype: int64
# None
# 1    9
# dtype: int64
# 0.6938888888888889
# 1
# 0.6938888888888889
# 0.67625
# 1
# 0.67625
# 0    11
# dtype: int64
# None
# 0    11
# dtype: int64
# 1.5
# 0
# 1.5
# 0    11
# dtype: int64
# None
# 0    11
# dtype: int64
# 0    15
# dtype: int64
# None
# 0    15
# dtype: int64
# 0    11
# dtype: int64
# None
# 0    11
# dtype: int64
# 0.46453125
# 7
# 0.46453125
# 0.7942142857142857
# 5
# 0.7942142857142857
# 3    11
# dtype: int64
# None
# 3    11
# dtype: int64
# 1.3333333333333333
# 0
# 1.3333333333333333
# 0.72
# 1
# 0.72
# 0    9
# dtype: int64
# None
# 0    9
# dtype: int64
# 0    10
# dtype: int64
# None
# 0    10
# dtype: int64
# 0    11
# dtype: int64
# None
# 0    11
# dtype: int64
# 0.5772222222222221
# 2
# 0.5772222222222221
# 1.9576250000000002
# 4
# 1.9576250000000002
# 0    17
# dtype: int64
# None
# 0    17
# dtype: int64
# 2    12
# dtype: int64
# None
# 2    12
# dtype: int64
# 0.19999999999999998
# 3
# 0.19999999999999998
# 1.6666666666666667
# 0
# 1.6666666666666667
# 0    12
# dtype: int64
# None
# 0    12
# dtype: int64
# 0.695
# 1
# 0.695
# 0    10
# dtype: int64
# None
# 0    10
# dtype: int64
# 0    29
# dtype: int64
# None
# 0    29
# dtype: int64
# 1    11
# dtype: int64
# None
# 1    11
# dtype: int64
# 0.569557142857143
# 7
# 0.569557142857143
# 0.42217187500000003
# 6
# 0.42217187500000003
# 0.5107916666666668
# 7
# 0.5107916666666668
# 0.698913043478261
# 1
# 0.698913043478261
# 1.77975
# 4
# 1.77975
# 0.5435714285714286
# 2
# 0.5435714285714286
# 0.6816666666666666
# 1
# 0.6816666666666666
# 0.675
# 1
# 0.675
# 0    11
# dtype: int64
# None
# 0    11
# dtype: int64
# 0    12
# dtype: int64
# None
# 0    12
# dtype: int64
# 0    12
# dtype: int64
# None
# 0    12
# dtype: int64
# 1.5
# 0
# 1.5
# 1    11
# dtype: int64
# None
# 1    11
# dtype: int64
# 0.69
# 1
# 0.69
# 0    16
# dtype: int64
# None
# 0    16
# dtype: int64
# 0    11
# dtype: int64
# None
# 0    11
# dtype: int64
# 1.6
# 0
# 1.6
# 1    10
# dtype: int64
# None
# 1    10
# dtype: int64
# 0.18499999999999997
# 3
# 0.18499999999999997
# 0    10
# dtype: int64
# None
# 0    10
# dtype: int64
# 1    11
# dtype: int64
# None
# 1    11
# dtype: int64
# 0.4930454545454545
# 7
# 0.4930454545454545
# 0.37570000000000003
# 6
# 0.37570000000000003
# 0.5599999999999999
# 2
# 0.5599999999999999
# 0    13
# dtype: int64
# None
# 0    13
# dtype: int64
# 1    10
# dtype: int64
# None
# 1    10
# dtype: int64
# 1.5
# 0
# 1.5
# 0    11
# dtype: int64
# None
# 0    11
# dtype: int64
# 0    12
# dtype: int64
# None
# 0    12
# dtype: int64
# 0.7241666666666665
# 1
# 0.7241666666666665
# 1    12
# dtype: int64
# None
# 1    12
# dtype: int64
# 0.735
# 1
# 0.735
# 0    13
# dtype: int64
# None
# 0    13
# dtype: int64
# 0    12
# dtype: int64
# None
# 0    12
# dtype: int64
# 0.5379615384615385
# 7
# 0.5379615384615385
# 0.5433333333333333
# 2
# 0.5433333333333333
# 0.6625000000000001
# 1
# 0.6625000000000001
# 0    14
# dtype: int64
# None
# 0    14
# dtype: int64
# 0    12
# dtype: int64
# None
# 0    12
# dtype: int64
# 0.38875
# 6
# 0.38875
# 1    11
# dtype: int64
# None
# 1    11
# dtype: int64
# 0    12
# dtype: int64
# None
# 0    12
# dtype: int64
# 0.7164285714285715
# 1
# 0.7164285714285715
# 0.368625
# 6
# 0.368625
# 1.5
# 0
# 1.5
# 0    15
# dtype: int64
# None
# 0    15
# dtype: int64
# 0    9
# dtype: int64
# None
# 0    9
# dtype: int64
# 1    10
# dtype: int64
# None
# 1    10
# dtype: int64
# 0.7416666666666667
# 1
# 0.7416666666666667
# 0.7324999999999999
# 1
# 0.7324999999999999
# 0    14
# dtype: int64
# None
# 0    14
# dtype: int64
# 0    11
# dtype: int64
# None
# 0    11
# dtype: int64
# 0    14
# dtype: int64
# None
# 0    14
# dtype: int64
# 0.7235714285714286
# 1
# 0.7235714285714286
# 0.707857142857143
# 1
# 0.707857142857143
# 0.696
# 1
# 0.696
# 1.883
# 4
# 1.883
# 0    19
# dtype: int64
# None
# 0    19
# dtype: int64
# 0    13
# dtype: int64
# None
# 0    13
# dtype: int64
# 0    10
# dtype: int64
# None
# 0    10
# dtype: int64
# 1.3333333333333333
# 0
# 1.3333333333333333
# 0.20333333333333334
# 3
# 0.20333333333333334
# 0.7166666666666667
# 1
# 0.7166666666666667
# 0    13
# dtype: int64
# None
# 0    13
# dtype: int64
# 0.5725
# 2
# 0.5725
# 0    11
# dtype: int64
# None
# 0    11
# dtype: int64
# 0    13
# dtype: int64
# None
# 0    13
# dtype: int64
# 2    11
# dtype: int64
# None
# 2    11
# dtype: int64
# 0.7166666666666667
# 1
# 0.7166666666666667
# 0    11
# dtype: int64
# None
# 0    11
# dtype: int64
# 0.565
# 2
# 0.565
# 0    9
# dtype: int64
# None
# 0    9
# dtype: int64
# 0    10
# dtype: int64
# None
# 0    10
# dtype: int64
# 0.5031428571428572
# 6
# 0.5031428571428572
# 0.207
# 3
# 0.207
# 0.7333333333333334
# 1
# 0.7333333333333334
# 0    9
# dtype: int64
# None
# 0    9
# dtype: int64
# 0    12
# dtype: int64
# None
# 0    12
# dtype: int64
# 0.74
# 1
# 0.74
# 0    10
# dtype: int64
# None
# 0    10
# dtype: int64
# 0    11
# dtype: int64
# None
# 0    11
# dtype: int64
# 0.19833333333333333
# 3
# 0.19833333333333333
# 2.2237
# 4
# 2.2237
# 0    11
# dtype: int64
# None
# 0    11
# dtype: int64
# 0.7433333333333333
# 1
# 0.7433333333333333
# 0.7324999999999999
# 1
# 0.7324999999999999
# 0    9
# dtype: int64
# None
# 0    9
# dtype: int64
# 0    11
# dtype: int64
# None
# 0    11
# dtype: int64
# 0    12
# dtype: int64
# None
# 0    12
# dtype: int64
# 0.7437499999999999
# 1
# 0.7437499999999999
# 1    13
# dtype: int64
# None
# 1    13
# dtype: int64
# 1    11
# dtype: int64
# None
# 1    11
# dtype: int64
# 0.6535365853658536
# 7
# 0.6535365853658536
# 0.9372407407407409
# 5
# 0.9372407407407409
# 0.41473333333333345
# 6
# 0.41473333333333345
# 1.4444444444444444
# 0
# 1.4444444444444444
# 0.5700000000000001
# 2
# 0.5700000000000001
# 0.6775
# 1
# 0.6775
# 0    22
# dtype: int64
# None
# 0    22
# dtype: int64
# 0    11
# dtype: int64
# None
# 0    11
# dtype: int64
# 2.0261666666666667
# 4
# 2.0261666666666667
# 0    10
# dtype: int64
# None
# 0    10
# dtype: int64
# 0    11
# dtype: int64
# None
# 0    11
# dtype: int64
# 0.38
# 6
# 0.38
# 0.7
# 1
# 0.7
# 0    20
# dtype: int64
# None
# 0    20
# dtype: int64
# 0    11
# dtype: int64
# None
# 0    11
# dtype: int64
# 1    13
# dtype: int64
# None
# 1    13
# dtype: int64
# 1.5
# 0
# 1.5
# 0.7166666666666667
# 1
# 0.7166666666666667
# 0.695
# 1
# 0.695
# 0    19
# dtype: int64
# None
# 0    19
# dtype: int64
# 0    20
# dtype: int64
# None
# 0    20
# dtype: int64
# 0    13
# dtype: int64
# None
# 0    13
# dtype: int64
# 0.7200000000000001
# 1
# 0.7200000000000001
# 0.7075
# 1
# 0.7075
# 0    14
# dtype: int64
# None
# 0    14
# dtype: int64
# 0    12
# dtype: int64
# None
# 0    12
# dtype: int64
# 0    18
# dtype: int64
# None
# 0    18
# dtype: int64
# 1.3333333333333333
# 0
# 1.3333333333333333
# 0.6141874999999999
# 7
# 0.6141874999999999
# 0.7333333333333334
# 1
# 0.7333333333333334
# 0    17
# dtype: int64
# None
# 0    17
# dtype: int64
# 0.7725
# 1
# 0.7725
# 0    10
# dtype: int64
# None
# 0    10
# dtype: int64
# 0    12
# dtype: int64
# None
# 0    12
# dtype: int64
# 0    12
# dtype: int64
# None
# 0    12
# dtype: int64
# 0.5912499999999999
# 2
# 0.5912499999999999
# 1    10
# dtype: int64
# None
# 1    10
# dtype: int64
# 0    11
# dtype: int64
# None
# 0    11
# dtype: int64
# 0.21607142857142855
# 3
# 0.21607142857142855
# 2.2219166666666665
# 4
# 2.2219166666666665
# 1.3333333333333333
# 0
# 1.3333333333333333
# 0.7024999999999999
# 1
# 0.7024999999999999
# 0    15
# dtype: int64
# None
# 0    15
# dtype: int64
# 0    18
# dtype: int64
# None
# 0    18
# dtype: int64
# 0    24
# dtype: int64
# None
# 0    24
# dtype: int64
# 1.3333333333333333
# 0
# 1.3333333333333333
# 0.7525
# 1
# 0.7525
# 0    14
# dtype: int64
# None
# 0    14
# dtype: int64
# 0    11
# dtype: int64
# None
# 0    11
# dtype: int64
# 0    12
# dtype: int64
# None
# 0    12
# dtype: int64
# 0.7755625
# 7
# 0.7755625
# 0.5700000000000001
# 2
# 0.5700000000000001
# 2.0
# 0
# 2.0
# 0    14
# dtype: int64
# None
# 0    14
# dtype: int64
# 0    10
# dtype: int64
# None
# 0    10
# dtype: int64
# 0    16
# dtype: int64
# None
# 0    16
# dtype: int64
# 0.73125
# 1
# 0.73125
# 0.7033333333333333
# 1
# 0.7033333333333333
# 0    27
# dtype: int64
# None
# 0    27
# dtype: int64
# 0    17
# dtype: int64
# None
# 0    17
# dtype: int64
# 0    14
# dtype: int64
# None
# 0    14
# dtype: int64

# %%
def predict_row(x,node):
    while len(x) > 0:
        while node.isLeaf == False: 
            attr_var = x[node.category] 
            if attr_var <= node.data:
                child_node = node.children[0]
            elif attr_var > node.data:
                child_node = node.children[1]
            if child_node.isLeaf: 
                return child_node.data.values.item()
            node = child_node

# %%
def predict(X, node):
    counter = 0
    copy = X.copy()
    result = {}
    for i in X.values: 
        result[counter] = (predict_row(i,node))
        counter += 1
    return result

# %%
pred = predict(X_test, n)
print(pred)
# Out:
# {0: 9, 1: 8, 2: 9, 3: 11, 4: 13, 5: 9, 6: 9, 7: 8, 8: 5, 9: 8, 10: 15, 11: 9, 12: 13, 13: 7, 14: 8, 15: 20, 16: 13, 17: 12, 18: 11, 19: 7, 20: 24, 21: 9, 22: 9, 23: 11, 24: 8, 25: 7, 26: 9, 27: 9, 28: 8, 29: 11, 30: 14, 31: 7, 32: 7, 33: 15, 34: 9, 35: 6, 36: 4, 37: 1, 38: 11, 39: 8, 40: 11, 41: 24, 42: 8, 43: 11, 44: 9, 45: 12, 46: 9, 47: 8, 48: 8, 49: 5, 50: 5, 51: 25, 52: 9, 53: 6, 54: 5, 55: 13, 56: 10, 57: 17, 58: 6, 59: 9, 60: 11, 61: 21, 62: 8, 63: 7, 64: 8, 65: 9, 66: 4, 67: 7, 68: 9, 69: 12, 70: 10, 71: 10, 72: 8, 73: 8, 74: 9, 75: 11, 76: 16, 77: 11, 78: 15, 79: 8, 80: 14, 81: 14, 82: 12, 83: 15, 84: 5, 85: 10, 86: 9, 87: 15, 88: 9, 89: 11, 90: 11, 91: 8, 92: 10, 93: 11, 94: 8, 95: 11, 96: 7, 97: 8, 98: 13, 99: 5, 100: 12, 101: 17, 102: 10, 103: 9, 104: 7, 105: 11, 106: 11, 107: 14, 108: 10, 109: 9, 110: 9, 111: 9, 112: 19, 113: 10, 114: 8, 115: 4, 116: 8, 117: 12, 118: 12, 119: 9, 120: 9, 121: 10, 122: 15, 123: 8, 124: 12, 125: 11, 126: 11, 127: 9, 128: 11, 129: 12, 130: 14, 131: 8, 132: 9, 133: 5, 134: 7, 135: 7, 136: 9, 137: 10, 138: 5, 139: 13, 140: 8, 141: 12, 142: 7, 143: 13, 144: 13, 145: 10, 146: 9, 147: 14, 148: 10, 149: 17, 150: 10, 151: 8, 152: 8, 153: 10, 154: 8, 155: 8, 156: 16, 157: 6, 158: 8, 159: 5, 160: 10, 161: 6, 162: 10, 163: 13, 164: 6, 165: 12, 166: 17, 167: 8, 168: 10, 169: 9, 170: 16, 171: 12, 172: 14, 173: 10, 174: 7, 175: 8, 176: 8, 177: 12, 178: 8, 179: 10, 180: 13, 181: 11, 182: 6, 183: 8, 184: 6, 185: 8, 186: 8, 187: 11, 188: 10, 189: 5, 190: 8, 191: 15, 192: 16, 193: 11, 194: 10, 195: 9, 196: 11, 197: 12, 198: 12, 199: 14, 200: 10, 201: 19, 202: 8, 203: 11, 204: 7, 205: 15, 206: 12, 207: 10, 208: 7, 209: 10, 210: 7, 211: 9, 212: 11, 213: 6, 214: 11, 215: 10, 216: 9, 217: 6, 218: 10, 219: 14, 220: 10, 221: 9, 222: 12, 223: 10, 224: 9, 225: 6, 226: 8, 227: 11, 228: 9, 229: 9, 230: 5, 231: 13, 232: 11, 233: 14, 234: 10, 235: 13, 236: 13, 237: 6, 238: 6, 239: 9, 240: 11, 241: 16, 242: 8, 243: 8, 244: 7, 245: 8, 246: 11, 247: 8, 248: 7, 249: 6, 250: 7, 251: 9, 252: 12, 253: 6, 254: 11, 255: 14, 256: 9, 257: 5, 258: 9, 259: 9, 260: 17, 261: 8, 262: 8, 263: 9, 264: 8, 265: 4, 266: 5, 267: 9, 268: 8, 269: 6, 270: 7, 271: 9, 272: 6, 273: 10, 274: 8, 275: 7, 276: 10, 277: 13, 278: 10, 279: 5, 280: 12, 281: 7, 282: 10, 283: 9, 284: 6, 285: 9, 286: 10, 287: 4, 288: 10, 289: 10, 290: 9, 291: 4, 292: 13, 293: 9, 294: 17, 295: 13, 296: 4, 297: 19, 298: 5, 299: 9, 300: 8, 301: 7, 302: 6, 303: 10, 304: 8, 305: 10, 306: 15, 307: 8, 308: 6, 309: 6, 310: 15, 311: 8, 312: 8, 313: 9, 314: 10, 315: 9, 316: 5, 317: 14, 318: 9, 319: 10, 320: 10, 321: 9, 322: 7, 323: 8, 324: 9, 325: 6, 326: 10, 327: 14, 328: 8, 329: 11, 330: 8, 331: 12, 332: 6, 333: 10, 334: 9, 335: 10, 336: 9, 337: 12, 338: 15, 339: 15, 340: 11, 341: 14, 342: 12, 343: 8, 344: 9, 345: 14, 346: 10, 347: 12, 348: 10, 349: 7, 350: 10, 351: 14, 352: 8, 353: 10, 354: 10, 355: 4, 356: 6, 357: 6, 358: 4, 359: 8, 360: 19, 361: 6, 362: 15, 363: 6, 364: 9, 365: 7, 366: 13, 367: 8, 368: 10, 369: 7, 370: 16, 371: 13, 372: 6, 373: 7, 374: 15, 375: 16, 376: 7, 377: 9, 378: 8, 379: 8, 380: 8, 381: 7, 382: 7, 383: 9, 384: 10, 385: 6, 386: 17, 387: 11, 388: 8, 389: 7, 390: 11, 391: 8, 392: 10, 393: 23, 394: 8, 395: 8, 396: 9, 397: 9, 398: 10, 399: 10, 400: 10, 401: 6, 402: 9, 403: 8, 404: 6, 405: 7, 406: 10, 407: 8, 408: 9, 409: 11, 410: 12, 411: 10, 412: 7, 413: 12, 414: 9, 415: 7, 416: 5, 417: 11, 418: 10, 419: 14, 420: 9, 421: 9, 422: 12, 423: 13, 424: 11, 425: 9, 426: 11, 427: 14, 428: 11, 429: 11, 430: 9, 431: 9, 432: 10, 433: 10, 434: 10, 435: 6, 436: 10, 437: 6, 438: 10, 439: 11, 440: 6, 441: 12, 442: 9, 443: 9, 444: 11, 445: 8, 446: 8, 447: 8, 448: 15, 449: 11, 450: 9, 451: 11, 452: 7, 453: 8, 454: 10, 455: 12, 456: 7, 457: 10, 458: 13, 459: 6, 460: 8, 461: 10, 462: 19, 463: 9, 464: 10, 465: 6, 466: 10, 467: 12, 468: 6, 469: 9, 470: 9, 471: 11, 472: 10, 473: 8, 474: 11, 475: 7, 476: 18, 477: 11, 478: 8, 479: 9, 480: 14, 481: 11, 482: 8, 483: 9, 484: 11, 4 ...

# %%
def accuracy(y_true, y_pred): 
        result = 0
        for idx, y_ in enumerate(y_pred.values()): 
            if y_ == y_true.values[idx]: result+=1
        return (result/len(y_true))

# %%
accuracy(y_test, pred)
# Out:
# 0.19808612440191387

# %%
def get_leaf(node):
    if node.isLeaf:
        return(node)
    else: 
        for child in node.children:
            return find_leaf(child)

# %%
def prune(X_pruning, y_pruning, current_node, prune_accuracy):
    print("1")
    if current_node.isLeaf: return
    for child in current_node.children:
        print(child.data)
        current_acc = prune_accuracy
        
        if child.isLeaf == True:
            y_ = predict(X_pruning, current_node)
            current_acc = accuracy(y_pruning, y_)
            dominant_class = (y_pruning.value_counts().argmax())/len(y_pruning)
            if dominant_class >= current_acc:
                current_node.isLeaf = True
                current_node.data = y_pruning.value_counts().argmax()
                current_node.children = []
                prune(X_pruning, y_pruning, current_node.parent, current_acc)
        else:
            print("jada")
            prune(X_pruning, y_pruning, child, current_acc)

# %%
def learn_new(X, y, impurity_measure='entropy', pruning=False):
    root = mnode()
    make_tree(X, y, root, impurity_measure)
    acc = predict(X, root)
    X_pruning, y_pruning = [],[]
    if pruning == True: 
        X, X_pruning, y, y_pruning = train_test_split(X,y, test_size=0.25, random_state=42)
        prune(X_pruning, y_pruning, root, acc)
    
    return root

# %%
n = learn_new(X_train, y_train, 'entropy', True)
# Out:
# 1
# 0.13220343137254903
# jada
# 1
# 0.2765394242803504
# jada
# 1
# 0.22159663865546197
# jada
# 1
# 0.024089403973509907
# jada
# 1
# 0.018020833333333323
# jada
# 1
# 0.008675675675675681
# jada
# 1
# 0.007176470588235295
# jada
# 1
# 0.10222222222222223
# jada
# 1
# 0.11833333333333335
# jada
# 1
# 0    1
# dtype: int64
# 1
# 9
# 0.005916666666666666
# jada
# 1
# 2    4
# dtype: int64
# 2.3333333333333335
# jada
# 1
# 0    3
# dtype: int64
# 1
# 2    4
# dtype: int64
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:11: FutureWarning:
# The current behaviour of 'Series.argmax' is deprecated, use 'idxmax'
# instead.
# The behavior of 'argmax' will be corrected to return the positional
# maximum in the future. For now, use 'series.values.argmax' or
# 'np.argmax(np.array(values))' to get the position of the maximum
# row.
#   # This is added back by InteractiveShellApp.init_path()
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:14: FutureWarning:
# The current behaviour of 'Series.argmax' is deprecated, use 'idxmax'
# instead.
# The behavior of 'argmax' will be corrected to return the positional
# maximum in the future. For now, use 'series.values.argmax' or
# 'np.argmax(np.array(values))' to get the position of the maximum
# row.
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-106-10075f21fb78> in <module>()
# ----> 1 n = learn_new(X_train, y_train, 'entropy', True)
#
# <ipython-input-105-cef9ddf47fa4> in learn_new(X, y, impurity_measure, pruning)
#       6     if pruning == True:
#       7         X, X_pruning, y, y_pruning = train_test_split(X,y, test_size=0.25, random_state=42)
# ----> 8         prune(X_pruning, y_pruning, root, acc)
#       9
#      10     return root
#
# <ipython-input-104-6cb7dc06019a> in prune(X_pruning, y_pruning, current_node, prune_accuracy)
#      17         else:
#      18             print("jada")
# ---> 19             prune(X_pruning, y_pruning, child, current_acc)
#
# <ipython-input-104-6cb7dc06019a> in prune(X_pruning, y_pruning, current_node, prune_accuracy)
#      17         else:
#      18             print("jada")
# ---> 19             prune(X_pruning, y_pruning, child, current_acc)
#
# <ipython-input-104-6cb7dc06019a> in prune(X_pruning, y_pruning, current_node, prune_accuracy)
#      17         else:
#      18             print("jada")
# ---> 19             prune(X_pruning, y_pruning, child, current_acc)
#
# <ipython-input-104-6cb7dc06019a> in prune(X_pruning, y_pruning, current_node, prune_accuracy)
#      17         else:
#      18             print("jada")
# ---> 19             prune(X_pruning, y_pruning, child, current_acc)
#
# <ipython-input-104-6cb7dc06019a> in prune(X_pruning, y_pruning, current_node, prune_accuracy)
#      17         else:
#      18             print("jada")
# ---> 19             prune(X_pruning, y_pruning, child, current_acc)
#
# <ipython-input-104-6cb7dc06019a> in prune(X_pruning, y_pruning, current_node, prune_accuracy)
#      17         else:
#      18             print("jada")
# ---> 19             prune(X_pruning, y_pruning, child, current_acc)
#
# <ipython-input-104-6cb7dc06019a> in prune(X_pruning, y_pruning, current_node, prune_accuracy)
#      17         else:
#      18             print("jada")
# ---> 19             prune(X_pruning, y_pruning, child, current_acc)
#
# <ipython-input-104-6cb7dc06019a> in prune(X_pruning, y_pruning, current_node, prune_accuracy)
#      17         else:
#      18             print("jada")
# ---> 19             prune(X_pruning, y_pruning, child, current_acc)
#
# <ipython-input-104-6cb7dc06019a> in prune(X_pruning, y_pruning, current_node, prune_accuracy)
#      17         else:
#      18             print("jada")
# ---> 19             prune(X_pruning, y_pruning, child, current_acc)
#
# <ipython-input-104-6cb7dc06019a> in prune(X_pruning, y_pruning, current_node, prune_accuracy)
#      14                 current_node.data = y_pruning.value_counts().argmax()
#      15                 current_node.children = []
# ---> 16                 prune(X_pruning, y_pruning, current_node.parent, current_acc)
#      17         else:
#      18             print("jada")
#
# <ipython-input-104-6cb7dc06019a> in prune(X_pruning, y_pruning, current_node, prune_accuracy)
#      17         else:
#      18             print("jada")
# ---> 19             prune(X_pruning, y_pruning, child, current_acc)
#
# <ipython-input-104-6cb7dc06019a> in prune(X_pruning, y_pruning, current_node, prune_accuracy)
#      17         else:
#      18             print("jada")
# ---> 19             prune(X_pruning, y_pruning, child, current_acc)
#
# <ipython-input-104-6cb7dc06019a> in prune(X_pruning, y_pruning, current_node, prune_accuracy)
#      14                 current_node.data = y_pruning.value_counts().argmax()
#      15                 current_node.children = []
# ---> 16                 prune(X_pruning, y_pruning, current_node.parent, current_acc)
#      17         else:
#      18             print("jada")
#
# <ipython-input-104-6cb7dc06019a> in prune(X_pruning, y_pruning, current_node, prune_accuracy)
#       7
#       8         if child.isLeaf == True:
# ----> 9             y_ = predict(X_pruning, current_node)
#      10             current_acc = accuracy(y_pruning, y_)
#      11             dominant_class = (y_pruning.value_counts().argmax())/len(y_pruning)
#
# <ipython-input-99-4aa249e9163b> in predict(X, node)
#       4     result = {}
#       5     for i in X.values:
# ----> 6         result[counter] = (predict_row(i,node))
#       7         counter += 1
#       8     return result
#
# <ipython-input-98-8fdfc3337365> in predict_row(x, node)
#       8                 child_node = node.children[1]
#       9             if child_node.isLeaf:
# ---> 10                 return child_node.data.values.item()
#      11             node = child_node
#
# AttributeError: 'numpy.int64' object has no attribute 'values'
